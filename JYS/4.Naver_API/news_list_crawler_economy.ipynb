# %% [markdown]
# # https://developers.naver.com/docs/serviceapi/search/news/news.md#뉴스

# %% [markdown]
# # display 최대100 (한 요청당이 겠지)
# # 모듈화 라는거 하면 더 빨리 긁을수 있을지도

# %% [markdown]
# # https://www.youtube.com/watch?v=C8-SII6S4Bc

# %%
# 뉴스 
# 호황/불황 

# 빅스 지수맹키로 산업에 대한 분위기를 알아낼 수 는 있다이

# 감성어 사전(지도학습) / (비지도) 
# 도메인 마다 단어의 의미가 달라짐 ㅇㅅㅇ -> 추가적인 작업이 필요할지도 노가다*100000

# 동사, 형용사, 부사 
# 없는건 중립으로 처리됨
# 강도 설정도

# 감성어 사전 그대로 써도 나의 머리는 터지게찌
# 안되면 추가로 만들어 보면 되징 ㅇㅅㅇ

# IT 업종지수

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re

# %%
client_id = "mNhJ01jj6_6mlvwLR3uy" # 개발자센터에서 발급받은 Client ID 값
client_secret = "JAHWSRUs2D" # 개발자센터에서 발급받은 Client Secret 값


#query = urllib.parse.quote(input("뭐가 그리 궁금하드노: "))
encText = urllib.parse.quote('경제')
idx = 0
display = 100
start = 1
end = 1000

web_df = pd.DataFrame(columns=('title', 'link', 'description', 'pubDate'))

for start_index in range(start, end, display): # 1 ~ 1000까지 100개씩 가지고 올끼야
    

    url = "https://openapi.naver.com/v1/search/news.json?query=" + encText \
            +'&display=' + str(display) \
            +'&sort=date' \
            +'&start=' + str(start_index)
             
    request = urllib.request.Request(url)

    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)

    response = urllib.request.urlopen(request)
    rescode = response.getcode()

    if(rescode==200):
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items'] 
        
        for item_index in range(0, len(items)):
            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag, '', items[item_index]['title'])
            link = items[item_index]['link']
            description = re.sub(remove_tag, '', items[item_index]['description'])
            pubDate = items[item_index]['pubDate']
            
            web_df.loc[idx] = [title, link, description, pubDate]
            idx += 1
            
    else: print("Error Code:" + rescode)

web_df
# Out:
#                                                  title  \
# 0                    이재명 “전두환, 경제에는 성과…박정희, 눈에 띄는 정치인”
# 1                                바이든, 숄츠 獨 총리와 첫 전화 회담
# 2                      바닷길 누비는 '경제안보 대사'?…미리 보는 한국형 항모
# 3           강원도 간 윤석열 “환경영향평가, 정답 없다...결국 정치적 판단으로 결정”
# 4    [EBN 오늘(11일) 이슈 종합] 삼성전자 '무선→MX사업부', 11월 고용도 호...
# ..                                                 ...
# 995        동성로 찾은 이재명 &quot;대구공항 이전터에 혁신 기업도시 건설&quot;
# 996                 대구 동성로 일대 이재명 보려고 몰린 지지자와 시민들로 북새통
# 997                        첫 통합형 수능 성적표 배부…예년보다 변수 많아져
# 998                    정부, 13일 대외경제장관회의 열고 CPTPP 가입 논의
# 999             文 &quot;한국, 권위주의에 시민혁명으로 민주주의 지켜&quot;
#
#                                                   link  \
# 0    https://news.naver.com/main/read.naver?mode=LS...
# 1    https://news.naver.com/main/read.naver?mode=LS...
# 2    https://news.naver.com/main/read.naver?mode=LS...
# 3    https://news.naver.com/main/read.naver?mode=LS...
# 4    https://www.ebn.co.kr/news/view/1511752/?sc=Naver
# ..                                                 ...
# 995  https://news.naver.com/main/read.naver?mode=LS...
# 996  https://www.yeongnam.com/web/view.php?key=2021...
# 997  https://news.naver.com/main/read.naver?mode=LS...
# 998  https://news.naver.com/main/read.naver?mode=LS...
# 999  https://news.naver.com/main/read.naver?mode=LS...
#
#                                            description  \
# 0    이 후보는 11일 경북 칠곡의 다부동 전적기념관을 방문한 자리에서 “전두환도 공과가...
# 1    바이든 부통령은 지난 7일 블라디미르 푸틴 러시아 대통령과 화상 정상회담 때 러시아...
# 2    특히 '경제안보'(economic securit) 시대인 오늘날엔 경항모가 과거보다...
# 3    ‘강원경제특별자치도’ 공약과 관련해 “해양수산부, 환경부 등 중앙정부의 규제를 철폐...
# 4    주요 경제 지표가 발표될 예정이다. 통계청은 오는 15일 11월 고용동향을 발표한다...
# ..                                                 ...
# 995  이재명 더불어민주당 대선후보가 10일 대구를 찾아 &quot;대구국제공항을 옮긴 자...
# 996  시민·청년들과 만나며 지역 경제 활성화는 물론이고 민주당에 대한 쓴소리도 마다하지 ...
# 997  우선, 수학에서 높은 점수를 받은 이과 수험생이 경제, 경영 등 문과계열로 지원하게...
# 998  정부가 오는 13일 대외경제장관회의를 열고 포괄적·점진적 환태평양경제동반자협정(CP...
# 999  다만 이번에도 중국에 대한 직접 언급은 없었으며, 이는 종전선언을 비롯한 한반도 문...
#
#                              pubDate
# 0    Sat, 11 Dec 2021 15:38:00 +0900
# 1    Sat, 11 Dec 2021 15:38:00 +0900
# 2    Sat, 11 Dec 2021 15:35:00 +0900
# 3    Sat, 11 Dec 2021 15:35:00 +0900
# 4    Sat, 11 Dec 2021 15:32:00 +0900
# ..                               ...
# 995  Fri, 10 Dec 2021 21:39:00 +0900
# 996  Fri, 10 Dec 2021 21:38:00 +0900
# 997  Fri, 10 Dec 2021 21:37:00 +0900
# 998  Fri, 10 Dec 2021 21:37:00 +0900
# 999  Fri, 10 Dec 2021 21:37:00 +0900
#
# [1000 rows x 4 columns]

# %%
web_df.columns
web_df["title_description"] = web_df["title"] + " " + web_df["description"]

# %%
web_df.to_csv("economy.csv", index=False, encoding="utf-8")
