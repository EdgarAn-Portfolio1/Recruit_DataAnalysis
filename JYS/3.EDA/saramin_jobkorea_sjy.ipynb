# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from collections import Counter
from nltk import WhitespaceTokenizer
import urllib
from wordcloud import WordCloud

# %%
#!pip install wordcloud

# %%
# 데이터 읽기
df = pd.read_csv(r'\Users\dataAnalysis-project\JYS\3.EDA\jobkorea_saramin_recruit.csv', index_col=0)
print(df.shape)
df.head(3)
# Out:
# (47645, 10)
#    resource     company                           duty career degree  \
# 0  jobkorea  디휴브(DEHUV)                 [디휴브] 개발자 부문채용  신입·경력   학력무관
# 1  jobkorea    ㈜레미유코스메틱  브랜드 디자이너 / MD / (카페)쇼룸 매니저 채용     경력   학력무관
# 2  jobkorea         ㈜순진       마케팅 담당자 및 상품기획/MD 경력직 채용  경력2년↑    고졸↑
#
#   work_place                  work_type  \
# 0     경기 고양시                        정규직
# 1     서울 성동구  정규직                 외\r\n
# 2     서울 광진구                        정규직
#
#                                             category  \
# 0  ['반응형 웹, 백엔드, 풀스택, 하이브리드 앱, 소프트웨어개발, BigData, ...
# 1  ['화장품, 마케팅, 마케팅기획, 브랜딩, 프로모션, 상품기획, 신상품개발, 온라인...
# 2  ['영상편집, 포토샵, 제품기획, 광고기획, 마케팅, 마케팅기획, 바이럴마케팅, 브...
#
#                                                 link  \
# 0  https://www.jobkorea.co.kr/Recruit/GI_Read/366...
# 1  https://www.jobkorea.co.kr/Recruit/GI_Read/366...
# 2  https://www.jobkorea.co.kr/Recruit/GI_Read/366...
#
#                                                 info
# 0  https://www.jobkorea.co.kr/Recruit/Co_Read/C/d...
# 1  https://www.jobkorea.co.kr/Recruit/Co_Read/C/l...
# 2  https://www.jobkorea.co.kr/Recruit/Co_Read/C/s...

# %%
df.describe()
# Out:
#         resource company     duty career degree work_place work_type  \
# count      47645   47645    47645  47645  47645      47645     47645
# unique         2   25206    44146    203     31        461        48
# top     jobkorea  ㈜엔씨소프트  백엔드 개발자   경력무관   학력무관     서울 강남구       정규직
# freq       29272     158       38  11868  24015       7087     36370
#
#                                             category  \
# count                                          47645
# unique                                         37650
# top     ['웹개발', '퍼블리셔', '프론트엔드', '반응형웹', '웹표준·웹접근성']
# freq                                             147
#
#                                                      link   info
# count                                               47645  47645
# unique                                              47423  17003
# top     https://www.jobkorea.co.kr/Recruit/GI_Read/364...      -
# freq                                                    2  18373

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47645 entries, 0 to 18372
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   resource    47645 non-null  object
#  1   company     47645 non-null  object
#  2   duty        47645 non-null  object
#  3   career      47645 non-null  object
#  4   degree      47645 non-null  object
#  5   work_place  47645 non-null  object
#  6   work_type   47645 non-null  object
#  7   category    47645 non-null  object
#  8   link        47645 non-null  object
#  9   info        47645 non-null  object
# dtypes: object(10)
# memory usage: 4.0+ MB

# %% [markdown]
# 컬럼별 고유값 확인해보기

# %% [markdown]
# ### 각 컬럼의 값 Count하기

# %%
df['company'].value_counts()
# Out:
# ㈜엔씨소프트                158
# 컴퓨터수리                 155
# ㈜조인아이티                117
# 세방정보시스템                85
# 이수정보㈜                  74
#                      ...
# AUTHENTIC WARDROBE      1
# 토이멀티샵                   1
# 셀러 이츠                   1
# 픽스플랜                    1
# (주)파폼                   1
# Name: company, Length: 25206, dtype: int64

# %%
df['duty'].value_counts()
# Out:
# 백엔드 개발자                         38
# 프론트엔드 개발자                       37
# 웹디자이너 모집                        25
# 웹디자이너 채용                        23
# 안드로이드 개발자                       17
#                                 ..
# [을지로/더존] ERP 프로젝트 투입 DBA         1
# [디펙트럼] 서버 개발자 모집                 1
# AMD 모집                           1
# 경력직 VM 엔지니어 모집                   1
# 서버·네트워크·보안/웹개발外 1개 부문 담당자 채용     1
# Name: duty, Length: 44146, dtype: int64

# %%
df['degree'].value_counts()
# Out:
# 학력무관         24015
# 초대졸↑          6945
# 대학교(4년)↑      4853
# 대학(2,3년)↑     4659
# 대졸↑           3879
# 고졸↑           2888
# 석사↑            308
# 경기 성남시          26
# 박사↑             23
# 박사              10
# 서울 중구            7
# 대구 동구            6
# 서울 강남구           4
# 서울 강남구 외         3
# 대전 유성구 외         2
# 서울 용산구           2
# 경기               1
# 인천 남동구 외         1
# 서울 은평구           1
# 서울 영등포구          1
# 세종 전지역           1
# 충북 음성군           1
# 세종 전지역 외         1
# 서울 마포구           1
# 대전 유성구           1
# 서울 금천구           1
# 서울 강서구 외         1
# 광주 북구            1
# 서울 강서구           1
# 대전 대덕구 외         1
# 인천 연수구           1
# Name: degree, dtype: int64

# %%
df['career'].value_counts()
# Out:
# 경력무관        11868
# 신입·경력        4107
# 신입 · 경력      3759
# 경력3년↑        3733
# 경력           2277
#             ...
# 8 ~ 16년         1
# 2 ~ 19년         1
# 12 ~ 20년        1
# 경력20년↑          1
# 6 ~ 8년          1
# Name: career, Length: 203, dtype: int64

# %%
df['work_place'].value_counts()
# Out:
# 서울 강남구      7087
# 서울 서초구      2482
# 서울 금천구      2382
# 서울 영등포구     1791
# 서울 구로구      1612
#             ...
# 경북 울진군 외       1
# 충남             1
# 전남 무안군 외       1
# 경북 군위군 외       1
# 전남 함평군 외       1
# Name: work_place, Length: 461, dtype: int64

# %%
df['work_type'].value_counts()
# Out:
# 정규직                          36370
# 정규직                 외\r\n     5214
# 계약직                           1836
# 계약직                 외\r\n     1399
# 정규직 · 계약직                     1391
# 인턴                             151
# 프리랜서                           143
# 정규직 · 병역특례                     143
# 계약직 · 프리랜서                     139
# 정규직 · 프리랜서                     138
# 정규직 · 인턴직                      112
# 계약직 · 파견직                       99
# -                               95
# 인턴직                             64
# 병역특례                            60
# 파견직                             40
# 정규직 · 파트                        37
# 계약직 · 아르바이트                     32
# 교육생                             31
# 아르바이트                           25
# 계약직 · 인턴직                       22
# 정규직 · 파견직                       19
# 정규직 · 해외취업                      15
# 정규직 · 전임                        11
# 인턴                 외\r\n         7
# 파트 · 아르바이트                       6
# 정규직 · 아르바이트                      6
# 파트 · 프리랜서                        5
# 아르바이트 · 프리랜서                     4
# 파트 · 계약직                         3
# 계약직 · 위촉직                        3
# 인턴직 · 아르바이트                      3
# 위촉직                              3
# 정규직 · 교육생                        3
# 위촉직 · 프리랜서                       2
# 정규직 · 위촉직                        2
# 인턴직 · 파견직                        1
# 파견직 · 해외취업                       1
# 해외취업                             1
# 교육생 · 해외취업                       1
# 파견직 · 위촉직                        1
# 계약직 · 병역특례                       1
# 파트                               1
# 파트 · 위촉직                         1
# 팀원                               1
# 3,000~5,000만원                    1
# 연수생/교육생                          1
# 전임 · 계약직                         1
# Name: work_type, dtype: int64

# %%
df['category'].value_counts()
# Out:
# ['웹개발', '퍼블리셔', '프론트엔드', '반응형웹', '웹표준·웹접근성']                                     147
# ['Java']                                                                         133
# ['백엔드/서버개발', '웹개발', '프론트엔드', 'DBA', 'SE(시스템엔지니어)']                                98
# ['백엔드/서버개발', '웹개발', '퍼블리셔', '프론트엔드', 'DBA']                                       97
# ['유지보수']                                                                          65
#                                                                                 ...
# ['오픈마켓, 데이터베이스, MySQL, SQL, 응용프로그래머, API, Application, Java']                      1
# ['프랜차이즈, 매출관리, 게임CS']                                                              1
# ['물류관리, 배송, 보세운송, 입출고관리, 출하, 일러스트레이터, 포토샵, 시각디자인']                                 1
# ['모바일, 모바일App, 스마트폰, 안드로이드, 영상편집, 그래픽디자인, 시각디자인, 일러스트레이터, 포토샵, 광고디자인, 시각디자인']      1
# ['백엔드/서버개발', '앱개발', '웹개발', '프론트엔드', '아키텍쳐']                                        1
# Name: category, Length: 37650, dtype: int64

# %% [markdown]
# ### 워드클라우드를 통해 상대적으로 빈도수가 높은 키워드 확인

# %%
tokenizer = WhitespaceTokenizer()
tokens1 = tokenizer.tokenize(' '.join(df['duty']))

# %%
counter1 = Counter(tokens1)
counter1.most_common(10)
# Out:
# [('채용', 14126),
#  ('모집', 10796),
#  ('개발자', 7070),
#  ('및', 6320),
#  ('개발', 3061),
#  ('/', 3018),
#  ('경력직', 2768),
#  ('정규직', 2521),
#  ('엔지니어', 2270),
#  ('경력', 2203)]

# %%
tokens2 = tokenizer.tokenize(' '.join(df['work_place']))
counter2 = Counter(tokens2)
counter2.most_common(20)
# Out:
# [('서울', 28532),
#  ('경기', 9502),
#  ('강남구', 7861),
#  ('외', 7776),
#  ('성남시', 3249),
#  ('서초구', 3001),
#  ('금천구', 2956),
#  ('영등포구', 2109),
#  ('구로구', 1912),
#  ('마포구', 1804),
#  ('중구', 1590),
#  ('서울전체', 1572),
#  ('송파구', 1439),
#  ('성동구', 1409),
#  ('부산', 1249),
#  ('인천', 1217),
#  ('대전', 1176),
#  ('강서구', 1136),
#  ('분당구', 1100),
#  ('대구', 801)]

# %%
wc = WordCloud(font_path=r'\Users\user\Downloads\NanumFontSetup_TTF_GOTHIC\NanumGothic.ttf')
result = wc.generate(' '.join(tokens2))

plt.figure(figsize=(12,12))
plt.imshow(result)
plt.show()

# %%
tokens3 = tokenizer.tokenize(' '.join(df['category']))
counter3 = Counter(tokens3)
counter3.most_common()
# Out:
# [('Java,', 5492),
#  ('쇼핑몰,', 5379),
#  ('포토샵,', 4525),
#  ('일러스트레이터,', 4111),
#  ("['백엔드/서버개발',", 3896),
#  ("'웹개발',", 3273),
#  ('바이럴마케팅,', 3192),
#  ("['소프트웨어개발,", 3110),
#  ('솔루션,', 3075),
#  ('웹프로그래머,', 2918),
#  ("'프론트엔드',", 2727),
#  ('오픈마켓,', 2631),
#  ('HTML,', 2582),
#  ('전자상거래,', 2509),
#  ('온라인마케팅,', 2493),
#  ('SI,', 2317),
#  ('소프트웨어개발,', 2306),
#  ('마케팅,', 2298),
#  ('웹사이트운영,', 2265),
#  ('유지보수,', 2056),
#  ("['웹개발',", 2052),
#  ('하드웨어,', 1992),
#  ('MySQL,', 1983),
#  ('마케팅기획,', 1867),
#  ('jsp,', 1850),
#  ('CSS,', 1830),
#  ('웹UI,', 1795),
#  ('웹기획,', 1776),
#  ("'Java',", 1748),
#  ('자바스크립트,', 1731),
#  ('안드로이드,', 1727),
#  ('Python,', 1726),
#  ('소셜마케팅,', 1724),
#  ("포토샵']", 1695),
#  ('SM,', 1643),
#  ('웹마케팅,', 1584),
#  ('응용프로그래머,', 1581),
#  ('키워드광고,', 1556),
#  ('SQL,', 1538),
#  ('Linux,', 1509),
#  ('컨텐츠관리,', 1489),
#  ("'C++',", 1442),
#  ('MD,', 1432),
#  ("['모바일앱개발,", 1428),
#  ('광고기획,', 1421),
#  ('모바일UI,', 1417),
#  ('온라인MD,', 1413),
#  ('아이폰,', 1405),
#  ('게시판관리,', 1398),
#  ("'유지보수',", 1393),
#  ("UI·UX디자인']", 1346),
#  ('영상편집,', 1337),
#  ("Java']", 1325),
#  ("['쇼핑몰,", 1323),
#  ("소프트웨어']", 1323),
#  ('웹서비스기획,', 1314),
#  ("'네트워크',", 1310),
#  ('상품기획,', 1306),
#  ("'SE(시스템엔지니어)',", 1297),
#  ("['상품기획,", 1275),
#  ('소셜커머스,', 1244),
#  ('네트워크관리,', 1240),
#  ('시각디자인,', 1218),
#  ('UI·UX디자인,', 1195),
#  ('모바일기획,', 1190),
#  ("'S/W',", 1178),
#  ('C#,', 1168),
#  ('C++,', 1153),
#  ('카페·블로그관리,', 1149),
#  ("['앱개발',", 1130),
#  ('프로모션,', 1127),
#  ('서버관리자,', 1107),
#  ('웹퍼블리셔,', 1091),
#  ('웹광고기획,', 1059),
#  ('소셜미디어,', 1044),
#  ('MS-SQL,', 1025),
#  ('네트워크엔지니어,', 1024),
#  ('컨텐츠개발,', 1016),
#  ('광고디자인,', 998),
#  ('Oracle,', 988),
#  ('시스템운영,', 978),
#  ("'R']", 963),
#  ("'C++']", 962),
#  ('SNS운영,', 954),
#  ('서버구축,', 948),
#  ("['기술지원',", 935),
#  ('컨텐츠기획,', 933),
#  ('.NET,', 913),
#  ('B2C,', 911),
#  ('브랜딩,', 909),
#  ('시장분석,', 907),
#  ('온라인광고,', 882),
#  ('펌웨어,', 877),
#  ("'HTML',", 875),
#  ("['유지보수',", 867),
#  ("'H/W',", 862),
#  ("'퍼블리셔',", 860),
#  ("'Android',", 859),
#  ('PM,', 858),
#  ("HTML']", 852),
#  ('C,', 820),
#  ('BigData,', 815),
#  ('스토리보드,', 802),
#  ("'C#',", 802),
#  ('그래픽디자인,', 794),
#  ('php,', 782),
#  ('HTML5,', 781),
#  ('정보보안,', 778),
#  ("'Java']", 778),
#  ("쇼핑몰']", 773),
#  ('유통관리,', 755),
#  ('홍보,', 745),
#  ('B2B,', 744),
#  ("컨텐츠관리']", 742),
#  ('컴퓨터,', 737),
#  ("['소셜커머스,", 735),
#  ("'정보보안',", 734),
#  ('보안관리,', 725),
#  ('API,', 719),
#  ("'앱개발',", 719),
#  ("['광고기획,", 716),
#  ('데이터베이스,', 698),
#  ("['데이터분석가',", 695),
#  ('HTML코딩,', 693),
#  ("['웹에이전시,", 692),
#  ('고객상담,', 683),
#  ('프리미어,', 669),
#  ('고객응대,', 667),
#  ('빅데이터,', 663),
#  ('인공지능(AI),', 657),
#  ('CS,', 648),
#  ('홍보기획,', 647),
#  ('웹표준,', 646),
#  ('광고대행,', 644),
#  ('재고관리,', 633),
#  ("'DBA',", 629),
#  ('기술지원,', 623),
#  ('상품입출고,', 621),
#  ("['유지보수,", 620),
#  ('광고관리,', 617),
#  ("SQL']", 617),
#  ('영업관리,', 611),
#  ("'API',", 610),
#  ('ERP,', 603),
#  ("'빅데이터',", 602),
#  ('AS,', 599),
#  ('웹프로모션,', 596),
#  ('고객관리,', 592),
#  ("'솔루션',", 590),
#  ('Application,', 587),
#  ('AJAX,', 586),
#  ('UI·UX,', 583),
#  ("'C언어',", 583),
#  ('소프트웨어,', 581),
#  ('asp,', 577),
#  ('컨텐츠,', 577),
#  ('모바일App,', 567),
#  ('기획,', 560),
#  ('영업지원,', 558),
#  ('광고제작,', 551),
#  ('물류,', 550),
#  ('제안·컨설팅,', 539),
#  ('고객지원,', 538),
#  ('기술영업,', 536),
#  ('UI설계,', 529),
#  ('게임개발,', 525),
#  ('DBA,', 518),
#  ('CSS3,', 517),
#  ('문서관리,', 515),
#  ("['SI,", 515),
#  ('방화벽,', 514),
#  ('AMD,', 509),
#  ('물류관리,', 508),
#  ("['UI·UX디자인,", 504),
#  ('서비스기획,', 503),
#  ('Windows,', 499),
#  ("웹사이트운영']", 497),
#  ("'유지보수']", 497),
#  ('컨텐츠에디터,', 486),
#  ("['퍼블리셔',", 483),
#  ('거래처관리,', 482),
#  ('웹접근성,', 481),
#  ('ASP.NET,', 477),
#  ("키워드광고']", 474),
#  ('GUI,', 470),
#  ("'인프라',", 470),
#  ('보안기술,', 467),
#  ("'iOS',", 464),
#  ('시스템분석,', 463),
#  ('사무보조,', 462),
#  ('인터넷쇼핑몰,', 462),
#  ('매출관리,', 461),
#  ('사업기획,', 457),
#  ("'웹디자인',", 454),
#  ("['게임개발',", 450),
#  ("['S/W',", 450),
#  ('시스템프로그래머,', 444),
#  ("PM']", 443),
#  ("'Linux',", 443),
#  ("'백엔드/서버개발',", 439),
#  ("'Javascript',", 438),
#  ("'.NET',", 438),
#  ("'클라우드',", 436),
#  ('업무제휴,', 435),
#  ("'머신러닝',", 432),
#  ('시스템설계,', 430),
#  ("['임베디드',", 430),
#  ('AE,', 422),
#  ('문서작성,', 417),
#  ('머신러닝(ML),', 412),
#  ('브랜드,', 411),
#  ('임베디드,', 411),
#  ("jsp']", 410),
#  ('CRM,', 409),
#  ('DW,', 407),
#  ("'솔루션']", 403),
#  ('전산전공,', 398),
#  ("프리미어']", 398),
#  ('이벤트,', 397),
#  ("['솔루션,", 396),
#  ("유지보수']", 389),
#  ("UI설계']", 389),
#  ("['모바일,", 381),
#  ('플래쉬,', 375),
#  ("'IT컨설팅',", 375),
#  ("php']", 372),
#  ("데이터분석']", 371),
#  ("A·S']", 370),
#  ("'AI(인공지능)',", 370),
#  ('드림위버,', 369),
#  ("'Windows',", 368),
#  ("['정보보안',", 363),
#  ('영업기획,', 360),
#  ("'펌웨어',", 359),
#  ('신상품개발,', 355),
#  ("'CSS',", 355),
#  ("'AWS',", 355),
#  ('정보설계,', 354),
#  ('일반영업,', 350),
#  ("['IT컨설팅',", 349),
#  ('PR,', 347),
#  ("Python']", 346),
#  ("'S/W']", 345),
#  ("Oracle']", 343),
#  ('모바일앱개발,', 336),
#  ('Sketch,', 336),
#  ("UI·UX']", 336),
#  ('게임기획,', 336),
#  ('스마트폰,', 332),
#  ('모바일게임,', 331),
#  ("'네트워크']", 331),
#  ("'Python',", 330),
#  ("'웹표준·웹접근성',", 329),
#  ('설치,', 328),
#  ("웹마케팅']", 326),
#  ("온라인마케팅']", 325),
#  ('Unix,', 324),
#  ("'방화벽',", 322),
#  ('Excel,', 320),
#  ('홍보대행,', 318),
#  ('패션MD,', 317),
#  ('QA,', 316),
#  ('전산입력,', 315),
#  ("['스토리지,", 315),
#  ('3DMax,', 314),
#  ('3D,', 312),
#  ("['네트웍구축,", 310),
#  ('시스템엔지니어,', 308),
#  ('홈페이지관리,', 307),
#  ("컨텐츠에디터']", 306),
#  ('전략,', 303),
#  ("['네트워크보안,", 300),
#  ('딥러닝,', 299),
#  ('통신,', 299),
#  ('디지털디자인,', 296),
#  ("['SE(시스템엔지니어)',", 296),
#  ('테스터,', 295),
#  ("Linux']", 294),
#  ('보안소프트웨어,', 293),
#  ('수리,', 293),
#  ("HTML5']", 293),
#  ("'MySQL',", 292),
#  ('통계·로그분석,', 291),
#  ("'Linux']", 291),
#  ('창고관리,', 289),
#  ('국내영업,', 288),
#  ("'정보통신',", 288),
#  ("['네트워크',", 288),
#  ('보안관제,', 285),
#  ('퍼블리싱,', 285),
#  ('포털,', 281),
#  ('게임디자인,', 281),
#  ("['H/W',", 281),
#  ("'Javascript']", 279),
#  ("정보보안']", 278),
#  ('방송CG,', 277),
#  ("Windows']", 277),
#  ("'Ajax',", 276),
#  ("HTML코딩']", 274),
#  ("['모바일App,", 274),
#  ("'데이터엔지니어',", 274),
#  ("안드로이드']", 271),
#  ('자재관리,', 270),
#  ("'C언어']", 270),
#  ("하드웨어']", 267),
#  ("['보안컨설팅',", 267),
#  ('기획조사,', 266),
#  ("['HTML',", 266),
#  ("['CSS',", 265),
#  ('WAS,', 264),
#  ("시각디자인']", 264),
#  ("'인프라']", 263),
#  ("['정보통신',", 262),
#  ("'HTML']", 261),
#  ('판매,', 257),
#  ('검증,', 256),
#  ("영상편집']", 254),
#  ("['게임개발,", 254),
#  ("'딥러닝',", 253),
#  ('커뮤니티,', 251),
#  ('법인영업,', 250),
#  ("'임베디드',", 248),
#  ("'반응형웹',", 248),
#  ('관리,', 247),
#  ('언론홍보,', 244),
#  ('xml,', 244),
#  ("'ERP',", 242),
#  ('솔루션영업,', 240),
#  ('인바운드TM,', 240),
#  ("'SE(시스템엔지니어)']", 240),
#  ('의류,', 239),
#  ('유통,', 238),
#  ("['QA/테스터',", 238),
#  ('PLC,', 236),
#  ('카메라,', 236),
#  ('판촉,', 234),
#  ("'API']", 234),
#  ('패션,', 233),
#  ("'Python']", 230),
#  ('모델링,', 228),
#  ('모바일앱게임,', 228),
#  ('인코딩,', 228),
#  ('영상디자인,', 227),
#  ('사무관리,', 226),
#  ("'Android']", 226),
#  ("'iOS']", 225),
#  ('증강현실,', 223),
#  ("카페·블로그관리']", 223),
#  ("'AWS']", 222),
#  ('SCM,', 218),
#  ("'R',", 218),
#  ('파이널컷,', 216),
#  ('거래선개발관리,', 215),
#  ("['유통,", 215),
#  ('회원관리,', 215),
#  ('데이터분석,', 213),
#  ("'웹표준·웹접근성']", 213),
#  ("['프론트엔드',", 212),
#  ("'기술지원',", 212),
#  ('웹에이전시,', 211),
#  ("'클라우드']", 206),
#  ('DataMining,', 205),
#  ('회로설계,', 205),
#  ('요구분석,', 205),
#  ("['광고대행,", 204),
#  ('개발,', 203),
#  ('경영기획,', 203),
#  ('리테일MD,', 203),
#  ('제품디자인,', 203),
#  ("'MSSQL',", 203),
#  ("['상세페이지,", 202),
#  ("['웹프로그래머,", 201),
#  ('제어,', 200),
#  ('사무행정,', 199),
#  ('게임소프트웨어,', 199),
#  ('MiPlatform,', 197),
#  ("'IoT',", 197),
#  ("['C#',", 196),
#  ("'OracleDB',", 196),
#  ("'ASP',", 196),
#  ('전기·전자회로,', 192),
#  ('신규사업·BD,', 191),
#  ('온라인광고영업,', 191),
#  ('전기,', 190),
#  ("'QA/테스터',", 189),
#  ("'MySQL']", 189),
#  ("'PHP',", 189),
#  ('디자인,', 188),
#  ('시스템영업,', 187),
#  ("C#']", 186),
#  ("['머신러닝',", 186),
#  ('판매관리,', 185),
#  ("['화장품,", 183),
#  ("웹프로모션']", 183),
#  ('VisualC++,', 182),
#  ('IT학원,', 182),
#  ("['전자상거래,", 181),
#  ('워드,', 180),
#  ("시스템운영']", 180),
#  ("'프론트엔드']", 180),
#  ("'SAP',", 180),
#  ('정비,', 178),
#  ("['Java',", 178),
#  ('SPRING,', 177),
#  ('JavaScript,', 177),
#  ("'사이트관리',", 176),
#  ("QA']", 175),
#  ("'알고리즘',", 174),
#  ("'JSP']", 174),
#  ("'C#']", 174),
#  ('게임운영관리,', 173),
#  ('영어,', 172),
#  ('전산회계,', 171),
#  ("'데이터마이닝',", 171),
#  ("'빅데이터']", 171),
#  ('경영지원,', 170),
#  ('HMI,', 169),
#  ('MFC,', 169),
#  ("'기술영업',", 169),
#  ('데이터마이닝,', 168),
#  ('모바일,', 165),
#  ("['소셜네트워크서비스(SNS),", 164),
#  ('웹PD,', 163),
#  ('광고영업,', 163),
#  ("자바스크립트']", 163),
#  ("MySQL']", 163),
#  ('가맹점관리,', 162),
#  ("디자인기타']", 162),
#  ('네트워크영업,', 161),
#  ("['DBA',", 161),
#  ("'JSP',", 161),
#  ("'Git',", 161),
#  ('Embedded,', 160),
#  ('회계,', 160),
#  ('결산,', 158),
#  ('캐주얼게임,', 158),
#  ('패키지디자인,', 157),
#  ('콜센터,', 157),
#  ("'PHP']", 157),
#  ("'보안컨설팅',", 157),
#  ("'일러스트레이터',", 157),
#  ("'SQL']", 156),
#  ('보안컨설팅,', 155),
#  ('사용자평가,', 154),
#  ("['물류,", 154),
#  ('식품MD,', 153),
#  ('기구설계,', 153),
#  ('웹디자인,', 153),
#  ("['웹디자인,", 153),
#  ('OA,', 152),
#  ('VMD,', 152),
#  ("['네트워크관리,", 152),
#  ("'모델링',", 152),
#  ('CCNA,', 151),
#  ('해외영업,', 151),
#  ('납품관리,', 151),
#  ('e러닝,', 151),
#  ('웹프로덕션,', 151),
#  ('전기·전자,', 150),
#  ("'DBMS',", 150),
#  ("['마케팅,", 149),
#  ("'DBA']", 149),
#  ("'R&D;',", 148),
#  ("'회로설계',", 147),
#  ('React,', 146),
#  ('포토그래퍼,', 146),
#  ("시스템프로그래머']", 146),
#  ("웹프로그래머']", 146),
#  ("'H/W']", 146),
#  ('경리,', 144),
#  ("['펌웨어',", 144),
#  ("['인터넷교육,", 143),
#  ('총무,', 142),
#  ("['컨텐츠,", 142),
#  ("'VR(가상현실)',", 142),
#  ("['무역업,", 141),
#  ('모션그래픽,', 141),
#  ('BM,', 141),
#  ("['IT컨설팅,", 141),
#  ("'OracleDB']", 141),
#  ("'블록체인',", 141),
#  ("컨텐츠기획']", 140),
#  ('자재구매,', 139),
#  ('사업제휴,', 138),
#  ('전기설비,', 138),
#  ('IT컨설팅,', 138),
#  ('무선통신,', 138),
#  ('DSP,', 137),
#  ('홈쇼핑,', 137),
#  ('촬영보조,', 137),
#  ("Helpdesk']", 137),
#  ("['Java,", 137),
#  ('검색광고,', 136),
#  ('세무,', 135),
#  ("C++']", 135),
#  ("'MCU',", 135),
#  ("'기술지원']", 135),
#  ('jquery,', 134),
#  ('반도체,', 133),
#  ('BI,', 133),
#  ("['Java']", 133),
#  ('기계,', 132),
#  ('IMC,', 132),
#  ("'웹디자인']", 132),
#  ('외주관리,', 131),
#  ('CAD,', 131),
#  ('배송,', 130),
#  ('PowerPoint,', 129),
#  ('프로그램강의,', 129),
#  ('여성의류,', 129),
#  ('애니메이션,', 128),
#  ('PD·연출,', 128),
#  ("'Windows']", 128),
#  ('mHTML,', 127),
#  ("['디자인,", 126),
#  ("딥러닝']", 126),
#  ("['빅데이터',", 126),
#  ('정보처리,', 124),
#  ("'PhotoShop']", 124),
#  ("'정보통신']", 123),
#  ("'Spring']", 123),
#  ('인터넷방송,', 122),
#  ("['데이터엔지니어',", 122),
#  ('교육기획,', 121),
#  ('Servlet,', 121),
#  ('하드웨어영업,', 121),
#  ('납품영업,', 121),
#  ('사진촬영기사,', 121),
#  ("'SI개발',", 121),
#  ('FPGA,', 120),
#  ('구매관리,', 120),
#  ("Unix']", 120),
#  ('타당성분석,', 119),
#  ('매체광고영업,', 118),
#  ("'AI(인공지능)']", 118),
#  ('학원강사,', 117),
#  ('화장품,', 117),
#  ("'CSS']", 117),
#  ('게임마케팅,', 116),
#  ('방송제작,', 116),
#  ("자연어처리(NLP)']", 116),
#  ('Firmware,', 115),
#  ('CG,', 115),
#  ('RPG,', 115),
#  ("['자동제어,", 115),
#  ("'ABAP',", 115),
#  ("['C++',", 115),
#  ('게임운영,', 114),
#  ("['오픈마켓,", 114),
#  ('클라이언트개발,', 114),
#  ("'웹마스터',", 114),
#  ('온라인게임,', 113),
#  ("펌웨어']", 113),
#  ("'모바일디자인',", 113),
#  ('편집디자인(IBM),', 112),
#  ('리눅스,', 112),
#  ("'Git']", 112),
#  ('APM,', 111),
#  ('정보통신·IT,', 111),
#  ('프랜차이즈,', 111),
#  ('AWS,', 111),
#  ('R,', 111),
#  ("['SM,", 111),
#  ('e-Learning,', 110),
#  ('포스터디자인,', 110),
#  ('웹게임,', 110),
#  ('Delphi,', 109),
#  ('Hardware,', 109),
#  ('정보통신,', 109),
#  ("CSS']", 109),
#  ('컴퓨터학원강사,', 109),
#  ("['딥러닝',", 109),
#  ("'딥러닝']", 109),
#  ('인사,', 108),
#  ('물류센터,', 108),
#  ("PLC']", 108),
#  ("'.NET']", 108),
#  ('Apache,', 107),
#  ('2D,', 107),
#  ('사물인터넷(IoT),', 107),
#  ('아트디렉터,', 107),
#  ("'MFC',", 107),
#  ("'솔루션기술영업',", 107),
#  ('생산관리,', 106),
#  ('품질관리,', 106),
#  ('생산직,', 106),
#  ('연구원,', 106),
#  ('급여관리,', 106),
#  ('LAN,', 106),
#  ('게임시나리오,', 106),
#  ('소셜네트워크서비스(SNS),', 106),
#  ('EC,', 106),
#  ("응용프로그래머']", 106),
#  ("'A/S기사',", 106),
#  ('방송기획,', 105),
#  ('전자,', 104),
#  ("['일러스트레이터,", 104),
#  ("'방화벽']", 104),
#  ("'Kotlin']", 104),
#  ("['Windows',", 104),
#  ('Cisco,', 103),
#  ('제품개발,', 103),
#  ("['생활용품,", 103),
#  ("웹서비스기획']", 103),
#  ("'HTML5',", 103),
#  ('어셈블리,', 102),
#  ('산업디자인,', 102),
#  ('캐릭터,', 102),
#  ('해외마케팅,', 101),
#  ("['솔루션',", 101),
#  ('전자회로,', 100),
#  ("['인터넷방송,", 100),
#  ("'영업관리',", 100),
#  ("['컴퓨터,", 99),
#  ('프로모션대행,', 99),
#  ("WAS']", 99),
#  ("['ERP,", 99),
#  ('DataWarehouse,', 99),
#  ("['의료기기,", 98),
#  ("['SAP',", 98),
#  ("'마케팅기획',", 98),
#  ("'ERP']", 98),
#  ('매장관리,', 97),
#  ('SAP,', 97),
#  ("'그래픽디자인',", 97),
#  ('설계엔지니어,', 96),
#  ('베타테스트,', 96),
#  ('전단지디자인,', 96),
#  ('관리회계,', 95),
#  ('바이오,', 95),
#  ('인디자인,', 95),
#  ("Application']", 95),
#  ("GUI']", 95),
#  ("'DevOps',", 95),
#  ("['백엔드,", 94),
#  ('CI,', 94),
#  ("영상디자인']", 94),
#  ("['모바일기획,", 94),
#  ("'사무직',", 94),
#  ('병역특례,', 93),
#  ('기술연구소,', 93),
#  ('아웃바운드TM,', 93),
#  ('디자인강의,', 93),
#  ("'RDBMS',", 93),
#  ('Helpdesk,', 92),
#  ("가상현실']", 92),
#  ("'MSSQL']", 92),
#  ("'IT영업',", 92),
#  ("'UI/UX디자인',", 92),
#  ("'게임기획',", 92),
#  ('더존,', 91),
#  ('기술직,', 91),
#  ('대리점관리,', 91),
#  ("시스템엔지니어']", 91),
#  ("['여성의류,", 91),
#  ("'정비기사',", 91),
#  ('가맹점관리(SV),', 90),
#  ('C++Builder,', 89),
#  ("네트워크엔지니어']", 89),
#  ('전산편집,', 89),
#  ('VisualC,', 89),
#  ("VisualC++']", 89),
#  ("'웹기획',", 89),
#  ('품질,', 88),
#  ('프론트엔드,', 88),
#  ('PCB,', 88),
#  ('전시디자인,', 88),
#  ('인터넷교육,', 88),
#  ("'CSS3',", 88),
#  ("'Ajax']", 88),
#  ('vue.js,', 87),
#  ('출판기획,', 87),
#  ("'연구원',", 87),
#  ("['.NET',", 87),
#  ('VB.NET,', 86),
#  ('부가세신고,', 86),
#  ('카탈로그편집,', 86),
#  ("['데이터베이스,", 86),
#  ('슈퍼바이저,', 86),
#  ("['식품가공,", 86),
#  ('3D온라인게임,', 86),
#  ('콘솔게임,', 86),
#  ('DB2,', 85),
#  ("['온라인광고,", 85),
#  ('가맹점영업,', 85),
#  ("'영상처리',", 85),
#  ('POS,', 84),
#  ('가상현실,', 84),
#  ('시설관리,', 84),
#  ('스튜디오,', 84),
#  ("'SQL',", 84),
#  ("['Android',", 84),
#  ('전기설계,', 83),
#  ('nexacro,', 83),
#  ("'머신러닝']", 83),
#  ("'ECMAScript',", 83),
#  ("빅데이터']", 82),
#  ('편집디자인(MAC),', 82),
#  ('하둡(Hadoop),', 82),
#  ("요구분석']", 82),
#  ("['금융,", 82),
#  ("'펌웨어']", 82),
#  ('자산관리,', 81),
#  ('기계설계,', 81),
#  ('품질검사,', 81),
#  ('생명공학,', 81),
#  ('서비스홍보,', 81),
#  ('인테리어,', 80),
#  ('자재구매기획,', 80),
#  ('홍보상담,', 80),
#  ('IT학원강사,', 80),
#  ("'일러스트레이터']", 80),
#  ("'FPGA',", 80),
#  ("'알고리즘']", 80),
#  ("'콘텐츠관리',", 80),
#  ('교수설계,', 79),
#  ('생산,', 79),
#  ("Cisco']", 79),
#  ('연구관리,', 78),
#  ("['BigData,", 78),
#  ("'Unity',", 78),
#  ("'jQuery',", 78),
#  ("'React']", 78),
#  ("['Sketch,", 77),
#  ('잡화디자인,', 77),
#  ("크리에이티브디렉터']", 77),
#  ('제약,', 77),
#  ('방송기술,', 77),
#  ('검사,', 77),
#  ("['전자,", 77),
#  ("'Angular',", 77),
#  ('IOS,', 76),
#  ('정보처리기사,', 76),
#  ("'UI/UX디자인']", 76),
#  ("'모의해킹',", 76),
#  ("AE']", 75),
#  ('디스플레이,', 75),
#  ("['JavaScript,", 75),
#  ('WinForm,', 75),
#  ("'서비스기획',", 75),
#  ("'IoT']", 75),
#  ('전표입력,', 74),
#  ("['AWS,", 74),
#  ('R&D,', 74),
#  ('서버,', 74),
#  ("서버구축']", 74),
#  ("MS-SQL']", 74),
#  ("'Kotlin',", 74),
#  ('생산기술,', 73),
#  ("DBA']", 73),
#  ('Cloud,', 73),
#  ("'AR(증강현실)',", 73),
#  ("'Node.js',", 73),
#  ("['보안소프트웨어,", 72),
#  ("['통신,", 72),
#  ("'반응형웹']", 72),
#  ('웹마스터,', 71),
#  ('NODE.JS,', 71),
#  ("['.NET,", 71),
#  ("'IDC',", 71),
#  ("'콘텐츠기획',", 71),
#  ("'앱기획',", 71),
#  ('비품관리,', 70),
#  ('테스트엔지니어,', 70),
#  ('전기제어,', 70),
#  ("['성형외과,", 70),
#  ("API']", 70),
#  ('ISP,', 70),
#  ("'React',", 70),
#  ("['웹마스터',", 70),
#  ('재무회계,', 69),
#  ('ERP운용,', 69),
#  ('정보디자인,', 69),
#  ('실내건축,', 69),
#  ('반도체장비,', 69),
#  ('편집,', 69),
#  ("['커뮤니티,", 69),
#  ("['남성의류,", 69),
#  ("패키지디자인']", 69),
#  ("'웹개발']", 69),
#  ("'정보보안']", 69),
#  ('인사기획,', 68),
#  ('사보제작,', 68),
#  ('판매영업,', 68),
#  ('Pro-C,', 68),
#  ("['AI(인공지능)',", 68),
#  ('재무,', 67),
#  ('HDML,', 67),
#  ('실내디자인,', 67),
#  ('소비재,', 67),
#  ("제안·컨설팅']", 67),
#  ('단순홍보,', 67),
#  ("'Objective-C',", 67),
#  ("'PM(프로젝트매니저)',", 67),
#  ("'VDI',", 67),
#  ("'VisualC·C++',", 67),
#  ('네트워크보안,', 66),
#  ('전자통신,', 66),
#  ('메카트로닉스,', 66),
#  ('POP,', 66),
#  ('아케이드게임,', 66),
#  ("SM']", 66),
#  ("['모바일UI,", 66),
#  ('OLAP,', 66),
#  ("'MFC']", 66),
#  ("['클라우드',", 66),
#  ("'데이터분석가',", 66),
#  ("'기획']", 66),
#  ('경영혁신,', 65),
#  ('Kotlin,', 65),
#  ('출판,', 65),
#  ('교육상담,', 65),
#  ("포장']", 65),
#  ("컨텐츠개발']", 65),
#  ("['가구,", 65),
#  ("['유지보수']", 65),
#  ("'VisualC·C++']", 65),
#  ("'마케팅전략',", 65),
#  ('포장디자인,', 64),
#  ('통신기술,', 64),
#  ('건축설계,', 64),
#  ("광고디자인']", 64),
#  ("'DevOps']", 64),
#  ("'데이터시각화',", 64),
#  ('조직관리,', 63),
#  ('의료기기,', 63),
#  ("임베디드']", 63),
#  ('개발자,', 63),
#  ("포스터디자인']", 63),
#  ("시스템설계']", 63),
#  ("Pro-C']", 63),
#  ("'ECMAScript']", 63),
#  ("'총무',", 63),
#  ('GIT,', 62),
#  ('3D설계,', 62),
#  ('공정관리,', 62),
#  ('통신공사,', 62),
#  ('SWIFT,', 62),
#  ('옥외광고,', 62),
#  ('광고,', 62),
#  ('IDC,', 62),
#  ('운영,', 61),
#  ('인사통합,', 61),
#  ('채용·면접,', 61),
#  ('VoIP,', 61),
#  ('마이크로프로세서,', 61),
#  ('문서수발,', 61),
#  ('아바타디자인,', 61),
#  ('교재제작,', 61),
#  ("xml']", 61),
#  ("'jQuery']", 61),
#  ("['FPGA',", 61),
#  ('ABAP,', 60),
#  ('C#Builder,', 60),
#  ('잡화매장,', 60),
#  ('전기공사,', 60),
#  ("['하드웨어,", 60),
#  ('제품홍보,', 60),
#  ('해피콜,', 60),
#  ('디자인학원,', 60),
#  ("'설계엔지니어',", 60),
#  ("'영업지원',", 60),
#  ("'기술엔지니어',", 60),
#  ("'스크립트',", 60),
#  ('크리에이티브디렉터,', 59),
#  ('원가회계,', 59),
#  ('공무,', 59),
#  ('tensorflow,', 59),
#  ('제작,', 59),
#  ("웹퍼블리셔']", 59),
#  ("파이널컷']", 59),
#  ("'광고디자인',", 59),
#  ("['AR(증강현실)',", 59),
#  ("['영상편집,", 58),
#  ('인터넷생활정보,', 58),
#  ('품질보증,', 58),
#  ('AutoCad,', 58),
#  ('환경,', 58),
#  ('NI,', 58),
#  ('xPlatform,', 58),
#  ("tensorflow']", 58),
#  ('의상디자인,', 58),
#  ('코디네이터,', 58),
#  ("['모바일게임,", 58),
#  ("인공지능(AI)']", 58),
#  ("아이폰']", 58),
#  ('프리랜서,', 58),
#  ("'Spring',", 58),
#  ("'SAP']", 58),
#  ("'PhotoShop',", 58),
#  ('변화관리,', 57),
#  ('바이어관리,', 57),
#  ('교재컨텐츠개발,', 57),
#  ('네트웍구축,', 57),
#  ('건축시공,', 57),
#  ('수출입무역,', 57),
#  ("솔루션']", 57),
#  ("['소프트웨어개발']", 57),
#  ("'자동제어',", 57),
#  ('VPN,', 56),
#  ('섬유,', 56),
#  ('편집디자이너,', 56),
#  ('RF,', 56),
#  ('보드게임,', 56),
#  ('프로덕션,', 56),
#  ('부동산컨설팅,', 56),
#  ("'임베디드리눅스',", 56),
#  ("'사무보조',", 56),
#  ("'A/S기사']", 56),
#  ("'DBMS']", 56),
#  ("['ERP',", 56),
#  ('플래시APP,', 55),
#  ('Typescript,', 55),
#  ('장비영업,', 55),
#  ('신기술영업,', 55),
#  ("['전기,", 55),
#  ('Micom,', 55),
#  ('UI디자인,', 55),
#  ('여성캐주얼디자인,', 55),
#  ('챗봇(Chatbot),', 55),
#  ('클라우드,', 55),
#  ("캐릭터디자인']", 55),
#  ('Spark,', 55),
#  ("['C,", 55),
#  ('라이센싱,', 55),
#  ('OA강의,', 55),
#  ("['모델링',", 55),
#  ('원부자재관리,', 54),
#  ('기계설비,', 54),
#  ('섬유디자인,', 54),
#  ('애니메이터,', 54),
#  ('기업교육,', 54),
#  ("CAD']", 54),
#  ('택배,', 54),
#  ("웹기획']", 54),
#  ("['CRM,", 54),
#  ("'Flutter',", 54),
#  ("'Unix']", 54),
#  ("'GM(게임운영)',", 54),
#  ('VisualBasic,', 53),
#  ('식품가공,', 53),
#  ('백화점,', 53),
#  ("['마트,", 53),
#  ('조립,', 53),
#  ("['아이폰,", 53),
#  ("'Node.js']", 53),
#  ("['API',", 53),
#  ("'ASP']", 53),
#  ("'액션스크립트',", 53),
#  ("'MES',", 53),
#  ("'게임디자인',", 53),
#  ("'사업기획',", 53),
#  ("'PM(프로젝트매니저)']", 53),
#  ('Framework,', 52),
#  ("정보통신·IT']", 52),
#  ('교육,', 52),
#  ('카피라이터,', 52),
#  ('할인점,', 52),
#  ('SIGN,', 52),
#  ("서버관리자']", 52),
#  ('및', 52),
#  ("['기업교육,", 52),
#  ('BTL,', 52),
#  ('중국어,', 52),
#  ('OCP,', 52),
#  ("['모바일앱게임,", 52),
#  ('멀티미디어디자인,', 52),
#  ("'전기제어',", 52),
#  ("'Swift']", 52),
#  ('외자구매,', 51),
#  ('제조,', 51),
#  ('예산관리,', 51),
#  ('MMI,', 51),
#  ("['프랜차이즈,", 51),
#  ('일반학원강사,', 51),
#  ("머신러닝(ML)']", 51),
#  ("클라이언트개발']", 51),
#  ("['블록체인',", 51),
#  ('상사,', 50),
#  ('일본어,', 50),
#  ('전시기획,', 50),
#  ("['Oracle,", 50),
#  ("POP광고']", 50),
#  ("'블록체인']", 50),
#  ("'RDBMS']", 50),
#  ("'자율주행',", 50),
#  ("['QA/테스터']", 50),
#  ('4대보험,', 49),
#  ('무역,', 49),
#  ('바이어상담,', 49),
#  ('공간디자인,', 49),
#  ('전기회로,', 49),
#  ('CMO,', 49),
#  ('피부과,', 49),
#  ('무역사무,', 49),
#  ('베타테스터,', 49),
#  ("SAP']", 49),
#  ("['디스플레이,", 49),
#  ("'ASP.NET',", 49),
#  ('전기기사,', 48),
#  ...]

# %%
result = wc.generate(' '.join(tokens3))
plt.figure(figsize=(12,12))
plt.imshow(result)
plt.show()
