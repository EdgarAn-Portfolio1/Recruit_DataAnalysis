# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import pandas as pd

# %%
browser = webdriver.Chrome('/Users/sky/Downloads/chromedriver')
# Out:
# /var/folders/mh/q1r71q296q7grz41z51vbp6w0000gq/T/ipykernel_65644/4081734133.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome('/Users/sky/Downloads/chromedriver')

# %%
url = 'https://www.jobkorea.co.kr/Top100/?Main_Career_Type=1&Search_Type=1&BizJobtype_Bctgr_Code=10016&BizJobtype_Bctgr_Name=IT·인터넷&BizJobtype_Code=0&BizJobtype_Name=IT·인터넷+전체&Major_Big_Code=0&Major_Big_Name=전체&Major_Code=0&Major_Name=전체&Edu_Level_Code=9&Edu_Level_Name=전체&Edu_Level_Name=전체&MidScroll=0'

# %%
browser.get(url)

# %%
soup = BeautifulSoup(browser.page_source)
soup
# Out:
# /Users/sky/opt/miniconda3/lib/python3.8/site-packages/bs4/__init__.py:177: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 194 of the file /Users/sky/opt/miniconda3/lib/python3.8/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   warnings.warn(self.NO_PARSER_SPECIFIED_WARNING % dict(
# <html lang="ko"><head>
# <title>IT·인터넷 관련 현재 인기 공고 TOP100 | 잡코리아</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="//www.jobkorea.co.kr/favicon.ico?v1904091400" rel="SHORTCUT ICON"/>
# <link href="https://www.jobkorea.co.kr/top100/?Main_Career_Type=1&amp;Search_Type=1&amp;BizJobtype_Bctgr_Code=10016&amp;BizJobtype_Bctgr_Name=IT%c2%b7%ec%9d%b8%ed%84%b0%eb%84%b7&amp;BizJobtype_Code=0&amp;BizJobtype_Name=IT%c2%b7%ec%9d%b8%ed%84%b0%eb%84%b7%ec%a0%84%ec%b2%b4&amp;Major_Big_Code=0&amp;Major_Big_Name=%ec%a0%84%ec%b2%b4&amp;Major_Code=0&amp;Major_Name=%ec%a0%84%ec%b2%b4&amp;Edu_Level_Code=9&amp;MidScroll=0&amp;Edu_Level_Name=%ec%a0%84%ec%b2%b4&amp;Edu_Level_Name=%ec%a0%84%ec%b2%b4" rel="canonical"/>
# <link href="https://m.jobkorea.co.kr/top100/?Main_Career_Type=1&amp;Search_Type=1&amp;BizJobtype_Bctgr_Code=10016&amp;BizJobtype_Bctgr_Name=IT%c2%b7%ec%9d%b8%ed%84%b0%eb%84%b7&amp;BizJobtype_Code=0&amp;BizJobtype_Name=IT%c2%b7%ec%9d%b8%ed%84%b0%eb%84%b7%ec%a0%84%ec%b2%b4&amp;Major_Big_Code=0&amp;Major_Big_Name=%ec%a0%84%ec%b2%b4&amp;Major_Code=0&amp;Major_Name=%ec%a0%84%ec%b2%b4&amp;Edu_Level_Code=9&amp;MidScroll=0&amp;Edu_Level_Name=%ec%a0%84%ec%b2%b4&amp;Edu_Level_Name=%ec%a0%84%ec%b2%b4" media="only screen and (max-width: 640px)" rel="alternate"/>
# <link href="ios-app://569092652/https/m.jobkorea.co.kr/top100/?Main_Career_Type=1&amp;Search_Type=1&amp;BizJobtype_Bctgr_Code=10016&amp;BizJobtype_Bctgr_Name=IT%c2%b7%ec%9d%b8%ed%84%b0%eb%84%b7&amp;BizJobtype_Code=0&amp;BizJobtype_Name=IT%c2%b7%ec%9d%b8%ed%84%b0%eb%84%b7%ec%a0%84%ec%b2%b4&amp;Major_Big_Code=0&amp;Major_Big_Name=%ec%a0%84%ec%b2%b4&amp;Major_Code=0&amp;Major_Name=%ec%a0%84%ec%b2%b4&amp;Edu_Level_Code=9&amp;MidScroll=0&amp;Edu_Level_Name=%ec%a0%84%ec%b2%b4&amp;Edu_Level_Name=%ec%a0%84%ec%b2%b4" rel="alternate"/>
# <link href="android-app://com.jobkorea.app/https/m.jobkorea.co.kr/top100/?Main_Career_Type=1&amp;Search_Type=1&amp;BizJobtype_Bctgr_Code=10016&amp;BizJobtype_Bctgr_Name=IT%c2%b7%ec%9d%b8%ed%84%b0%eb%84%b7&amp;BizJobtype_Code=0&amp;BizJobtype_Name=IT%c2%b7%ec%9d%b8%ed%84%b0%eb%84%b7%ec%a0%84%ec%b2%b4&amp;Major_Big_Code=0&amp;Major_Big_Name=%ec%a0%84%ec%b2%b4&amp;Major_Code=0&amp;Major_Name=%ec%a0%84%ec%b2%b4&amp;Edu_Level_Code=9&amp;MidScroll=0&amp;Edu_Level_Name=%ec%a0%84%ec%b2%b4&amp;Edu_Level_Name=%ec%a0%84%ec%b2%b4" rel="alternate"/>
# <meta content="IT·인터넷 관련 현재 인기 공고 TOP100 | 잡코리아" name="title"/>
# <meta content="잡코리아" name="writer"/>
# <meta content="놓치면 후회하는 IT·인터넷 인기 공고! 매일 업데이트 되는 IT·인터넷 인기 채용공고를 지금 확인해보세요." name="description"/>
# <meta content="IT·인터넷 인기 채용, 인기 공고, TOP100, 베스트, 베스트 채용, 직무별 채용, 직무별 TOP100, 채용, 취업, 공채, 인턴, 이력서, 취업사이트" name="keywords"/>
# <meta content="wfOOCE9Vtx+Z5etOXJnS9LU03yGpBxkK74T/yU63Xqs=" name="verify-v1"/>
# <meta content="IT·인터넷 TOP100" property="og:site_name"/>
# <meta content="IT·인터넷 TOP100" property="og:title"/>
# <meta content="직무별 인기 공고를 확인해보세요." property="og:description"/>
# <meta content="//file1.jobkorea.co.kr/mailing/2018/share_20180314.png" property="og:image"/>
# <meta content="https://www.jobkorea.co.kr/Top100/?Search_Type=1&amp;Main_Career_Type=1&amp;BizJobtype_Bctgr_Code=10016&amp;BizJobtype_Bctgr_Name=IT·인터넷" property="og:url"/>
# <meta content="website" property="og:type"/>
# <!-- 키워드 스크립트 시작 -->
# <script src="https://teralog.techhub.co.kr/trk?la_tp=pv&amp;la_gc=TR10148105490&amp;la_uid=&amp;la_fid=2c96cdaea72e11460a3d35270c67c607&amp;la_sid=&amp;la_infl=&amp;la_pa1=&amp;la_pa2=&amp;la_dccs=UTF-8&amp;la_r=2087315363&amp;la_crsd_gc=&amp;la_sv=59647be&amp;la_dcrf=&amp;la_dcurl=https%3A%2F%2Fwww.jobkorea.co.kr%2FTop100%2F%3FMain_Career_Type%3D1%26Search_Type%3D1%26BizJobtype_Bctgr_Code%3D10016%26BizJobtype_Bctgr_Name%3DIT%25C2%25B7%25EC%259D%25B8%25ED%2584%25B0%25EB%2584%25B7%26BizJobtype_Code%3D0%26BizJobtype_Name%3DIT%25C2%25B7%25EC%259D%25B8%25ED%2584%25B0%25EB%2584%25B7%2B%25EC%25A0%2584%25EC%25B2%25B4%26Major_Big_Code%3D0%26Major_Big_Name%3D%25EC%25A0%2584%25EC%25B2%25B4%26Major_Code%3D0%26Major_Name%3D%25EC%25A0%2584%25EC%25B2%25B4%26Edu_Level_Code%3D9%26Edu_Level_Name%3D%25EC%25A0%2584%25EC%25B2%25B4%26Edu_Level_Name%3D%25EC%25A0%2584%25EC%25B2%25B4%26MidScroll%3D0&amp;la_dcttl=IT%C2%B7%EC%9D%B8%ED%84%B0%EB%84%B7%20%EA%B4%80%EB%A0%A8%20%ED%98%84%EC%9E%AC%20%EC%9D%B8%EA%B8%B0%20%EA%B3%B5%EA%B3%A0%20TOP100%20%7C%20%EC%9E%A1%EC%BD%94%EB%A6%AC%EC%95%84&amp;la_ib=&amp;la_is=&amp;la_callback=_LA.CB"></script><script src="https://teralog.techhub.co.kr/ckie"></script><script async="" src="https://connect.facebook.net/signals/config/1166416616740867?v=2.9.48&amp;r=stable"></script><script async="" src="https://connect.facebook.net/en_US/fbevents.js"></script><script async="" src="https://www.google-analytics.com/analytics.js"></script><script src="https://sas.nsm-corp.com/sa-w.js?gc=TR10148105490&amp;rd=1638498018597"></script><script src="https://partner.googleadservices.com/gampad/cookie.js?domain=www.jobkorea.co.kr&amp;callback=_gfp_s_&amp;client=ca-pub-2252464458280030"></script><script async="" src="//www.googleadservices.com/pagead/conversion_async.js" type="text/javascript"></script><script async="" src="//www.googleadservices.com/pagead/conversion_async.js" type="text/javascript"></script><script id="google_shimpl" src="https://pagead2.googlesyndication.com/pagead/managed/js/adsense/m202111170101/show_ads_impl_fy2019.js"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-PDF7GQ4"></script><script language="JavaScript">
#     var EchoID = "jobkorea";
#     var EchoGoodNm = "";
#     var EchoAmount = "";
#     var EchoUIP = "";
#     var EchoTarget = "";
#     var EchoLogSend = "Y";
#     var EchoCV = "";
#     var EchoPN = "";
# </script>
# <script src="/Scripts/EchoScriptV2.js" type="text/javascript"></script>
# <meta content="wfOOCE9Vtx+Z5etOXJnS9LU03yGpBxkK74T/yU63Xqs=" name="verify-v1"/>
# <link href="//i.jobkorea.kr/content/css/ver_2/event/banner.promotion-sv-202010291622.css" rel="stylesheet" type="text/css"/>
# <link href="//i.jobkorea.kr/content/css/ver_2/common-sv-202111021410.css" rel="stylesheet" type="text/css"/><link href="//i.jobkorea.kr/content/css/ver_2/gnb/gnb-sv-202111251745.css" rel="stylesheet" type="text/css"/><link href="//i.jobkorea.kr/content/css/ver_2/top100/top_style-sv-202011171729.css" rel="stylesheet" type="text/css"/><link href="//i.jobkorea.kr/deploy/pc/dist/css/personal/layout/footer-sv-202102181306.css" rel="stylesheet" type="text/css"/>
# <script src="/NET/bundles/JK5cript?v=kt6fvRQVnlFhtrZQRB60lIBi5ru4auyenJ3cQsNF3hg1"></script>
# <!--[if lt IE 9]>
#     <script src="https://i.jobkorea.kr/content/js/html5shiv.min.js"></script>
#     <script src="/include/js/respond.js"></script>
#     <![endif]-->
# <script src="/Scripts/Main/Common.js?202112011400" type="text/javascript"></script>
# <script src="https://i.jobkorea.kr/content/js/starter/uit_starter.min.js" type="text/javascript"></script>
# <script src="https://i.jobkorea.kr/content/js/starter/jquery.nanoscroller.js" type="text/javascript"></script>
# <script src="https://i.jobkorea.kr/content/js/sidebar.min.js?20180123" type="text/javascript"></script>
# <script id="dslog_tag" src="/resources/lib/datastory/dslog.js?ver=1.1" type="text/javascript"></script>
# <script type="text/javascript">
#  window.dsValDic = {};
#  window.dsTypeDic = {};
#  window.dsHelper = {
#  registVal: function (key, value) { window.dsValDic[key] = value; },
#  getVal: function (key) { return window.dsValDic[key]; },
#  removeVal: function (key) { delete (window.dsValDic[key]); },
#  clearVal: function () { window.dsValDic = {} },
#  registType: function (type) { window.dsTypeDic[type] = type; },
#  removeType: function (type) { delete (window.dsTypeDic[type]); },
#  clearType: function (type) { window.disTypeDic = {}; }
#  };
#  </script>
# <script>
# 	(function (w, d, s, l, i) {
# 	w[l] = w[l] || []; w[l].push({
# 		'gtm.start':
# 			new Date().getTime(), event: 'gtm.js'
# 	}); var f = d.getElementsByTagName(s)[0],
# 		j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
# 			'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
# 	})(window, document, 'script', 'dataLayer', 'GTM-PDF7GQ4');</script>
# <!-- End Google Tag Manager -->
# <!-- Google Ad Manager -->
# <script async="" data-ad-client="ca-pub-2252464458280030" data-checked-head="true" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- 상단 선언 스크립트 : 모든페이지 공통 상단 필수 -->
# <!-- PlayD TERA Log Definition Script Start -->
# <script>
#     window.onload = function () {
#         (function (win, name) {
#             win['LogAnalyticsObject'] = name;
#             win[name] = win[name] || function () { (win[name].q = win[name].q || []).push(arguments) }
#         })(window, '_LA');
#     }
# </script>
# <meta content="AxujKG9INjsZ8/gUq8+dTruNvk7RjZQ1oFhhgQbcTJKDnZfbzSTE81wvC2Hzaf3TW4avA76LTZEMdiedF1vIbA4AAABueyJvcmlnaW4iOiJodHRwczovL2ltYXNkay5nb29nbGVhcGlzLmNvbTo0NDMiLCJmZWF0dXJlIjoiVHJ1c3RUb2tlbnMiLCJleHBpcnkiOjE2NTI3NzQ0MDAsImlzVGhpcmRQYXJ0eSI6dHJ1ZX0=" http-equiv="origin-trial"/><meta content="" http-equiv="origin-trial"/><meta content="" http-equiv="origin-trial"/><meta content="" http-equiv="origin-trial"/><meta content="A88BWHFjcawUfKU3lIejLoryXoyjooBXLgWmGh+hNcqMK44cugvsI5YZbNarYvi3roc1fYbHA1AVbhAtuHZflgEAAAB2eyJvcmlnaW4iOiJodHRwczovL2dvb2dsZS5jb206NDQzIiwiZmVhdHVyZSI6IlRydXN0VG9rZW5zIiwiZXhwaXJ5IjoxNjUyNzc0NDAwLCJpc1N1YmRvbWFpbiI6dHJ1ZSwiaXNUaGlyZFBhcnR5Ijp0cnVlfQ==" http-equiv="origin-trial"/><meta content="" http-equiv="origin-trial"/><meta content="" http-equiv="origin-trial"/><meta content="" http-equiv="origin-trial"/><script src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/830972038/?random=1638498018106&amp;cv=9&amp;fst=1638498018106&amp;num=1&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;u_h=1024&amp;u_w=1366&amp;u_ah=999&amp;u_aw=1366&amp;u_cd=24&amp;u_his=2&amp;u_tz=540&amp;u_java=false&amp;u_nplug=5&amp;u_nmime=2&amp;gtm=2wgc10&amp;sendb=1&amp;ig=1&amp;frm=0&amp;url=https%3A%2F%2Fwww.jobkorea.co.kr%2FTop100%2F%3FMain_Career_Type%3D1%26Search_Type%3D1%26BizJobtype_Bctgr_Code%3D10016%26BizJobtype_Bctgr_Name%3DIT%25C2%25B7%25EC%259D%25B8%25ED%2584%25B0%25EB%2584%25B7%26BizJobtype_Code%3D0%26BizJobtype_Name%3DIT%25C2%25B7%25EC%259D%25B8%25ED%2584%25B0%25EB%2584%25B7%2B%25EC%25A0%2584%25EC%25B2%25B4%26Major_Big_Code%3D0%26Major_Big_Name%3D%25EC%25A0%2584%25EC%25B2%25B4%26Major_Code%3D0%26Major_Name%3D%25EC%25A0%2584%25EC%25B2%25B4%26Edu_Level_Code%3D9%26Edu_Level_Name%3D%25EC%25A0%2584%25EC%25B2%25B4%26Edu_Level_Name%3D%25EC%25A0%2584%25EC%25B2%25B4%26MidScroll%3D0&amp;tiba=IT%C2%B7%EC%9D%B8%ED%84%B0%EB%84%B7%20%EA%B4%80%EB%A0%A8%20%ED%98%84%EC%9E%AC%20%EC%9D%B8%EA%B8%B0%20%EA%B3%B5%EA%B3%A0%20TOP100%20%7C%20%EC%9E%A1%EC%BD%94%EB%A6%AC%EC%95%84&amp;hn=www.googleadservices.com&amp;async=1&amp;rfmt=3&amp;fmt=4"></script><script src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/1035272615/?random=1638498018179&amp;cv=9&amp;fst=1638498018179&amp;num=1&amp;label=%EB%A6%AC%EB%A7%88%EC%BC%80%ED%8C%85&amp;guid=ON&amp;resp=GooglemKTybQhCsO&a ...
# <body class="top100Main" id="" style="">
# <!--// top100Main 추가 -->
# <div id="skipNavigation">
# <p><a href="#container">메뉴 건너뛰기</a></p>
# </div>
# <hr/>
# <!--// GNB 개편 시작 -->
# <div class="gnbTheme1200 devGnbContainer " id="headerWrap">
# <div class="" id="header">
# <!--신입공채 메뉴일경우 클래스 start-sub 추가 -->
# <!-- // headInner -->
# <div class="headInner">
# <h1 class="jkLogo">
# <a href="https://www.jobkorea.co.kr"><img alt="끝이다른시작 JOBKOREA" src="https://i.jobkorea.kr/content/images/ver_1/gnb/jk_logo.png?20190718"/></a>
# </h1>
# <!-- // search -->
# <div class="search">
# <h2 class="skip">검색</h2>
# <form action="/Search/" autocomplete="off" id="AKCFrm" name="global_seek" onsubmit="return GoMainTotalSearch();" target="_self">
# <fieldset>
# <legend>Smart Match 통합검색</legend>
# <div class="smKey">
# <input id="stext" maxlength="50" name="stext" title="검색어 입력" type="text"/>
# <!-- // 기존 자동완성 들어갈 영역 -->
# <div class="autoSearch" id="AKCDiv">
# <!-- // 기능 끈 상황 -->
# <div class="autoSearchStop" id="SearchStop">
# <p class="btnArrow" id="btnArrow_C"><button class="devAcDisabledInfoOpen" title="열림" type="button"><span class="blind">열림</span></button></p>
# <div class="searchStopDesc" id="StopDesc">
# <p class="description">
#                                 키워드를 입력하시면<br/> 검색어와 채용정보를 추천해드립니다.
#                             </p>
# <p class="btnOdd">
# <button id="devAcOn" type="button">기능켜기</button> <span>|</span>
# <button class="odd" id="devAcInfoClose" type="button">닫기</button>
# </p>
# </div>
# <p class="btnArrow btnArrowClose" id="btnArrow_O"><button class="devAcDisabledInfoClose" title="닫힘" type="button"><span class="blind">닫힘</span></button></p>
# <div class="bg"></div>
# </div>
# <!-- // 기능 켠 상황 -->
# <div class="autoSearchStart" id="SearchStart">
# <div class="iframeHolder" data-allowtransparency="true" data-id="AKCIfrm" data-name="AKCIfrm" data-title="자동검색" data-url="https://www.jobkorea.co.kr/Main/_OneShotSearch"><iframe allowtransparency="true" frameborder="0" id="AKCIfrm" marginheight="0" marginwidth="0" name="AKCIfrm" scrolling="no" src="https://www.jobkorea.co.kr/Main/_OneShotSearch" title="자동검색"></iframe></div>
# <p class="btnOdd">
# <button class="odd" id="devAcOff" type="button">기능끄기</button>
# </p>
# <div class="bg"></div>
# </div>
# </div>
# <!-- 기존 자동완성 들어갈 영역 // -->
# <input class="submit spGnb" id="common_search_btn" type="submit" value="검색"/>
# </div>
# </fieldset>
# </form>
# </div>
# <!-- search // -->
# <div class="subSchArea">
# <!-- // 직무·지역 찾기 버튼 클릭시 active 클래스 추가 -->
# <div class="lyJoblistBx">
# <h2 class="skip">직무 지역 찾기</h2>
# <button class="btnJobList" type="button">
# <span class="spNav"><span class="txIr">직무·지역 찾기</span></span>
# </button>
# <!-- // 직무·지역 찾기 레이어 -->
# <div class="lyJobListWrap">
# <div class="lyJobListInner">
# <!-- // 직무 -->
# <div class="dutySec listArea active">
# <h3 class="titDuty"><button class="btnTabList" type="button"><span class="spNav"><span class="txIr">직무</span></span></button></h3>
# <div class="listRecent">
# <h4 class="titRecent">최근본</h4><ul class="subList dev-duty-item dev-rstn-item"></ul>
# </div>
# <div class="listWrap" id="devGnbDutyLayreArea"> <div class="listBx row01 begin">
# <dl>
# <dt><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;dutyCtgr=10012">경영·사무</a></dt>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000064">기획·전략·경영</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000065">사무·총무·법무</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000066">인사·노무·교육</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000069">경리·회계·결산</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000070">재무·세무·IR</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000068">사무보조·문서작성</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000067">비서·안내</a></dd>
# </dl>
# </div>
# <div class="listBx row01">
# <dl>
# <dt><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;dutyCtgr=10020">미디어</a></dt>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000130">감독·연출·PD</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000131">영상·사진·촬영</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000132">광고제작·카피·CF</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000133">아나운서·리포터·성우</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000134">기자</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000135">작가·시나리오</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000136">연예·엔터테인먼트</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000137">인쇄·출판·편집</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000138">영화·배급</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000139">음악·음향</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000140">공연·전시·무대·스텝</a></dd>
# </dl>
# </div>
# <div class="listBx row01">
# <dl>
# <dt><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;dutyCtgr=10025">전문·특수직</a></dt>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000182">경영분석·컨설턴트</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000181">채권·심사·보험·보상</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000180">회계·세무·CPA</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000178">노무·헤드헌터·직업상담</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000179">리서치·통계·설문</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000177">도서관사서</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000175">법률·특허·상표</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000174">외국어·번역·통역</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000173">보안·경호</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000176">사회복지·요양보호·자원봉사</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000184">연구소·R&amp;D</a></dd>
# </dl>
# </div>
# <div class="listBx row01">
# <dl>
# <dt><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;dutyCtgr=10015">영업·고객상담</a></dt>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000082">제품·서비스영업</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000083">금융·보험영업</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000084">IT·솔루션·기술영업</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000085">영업관리·지원·영업기획</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000086">광고영업</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000087">법인영업</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000088">판매·서빙·매장관리</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000092">단순홍보·회원관리</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000089">아웃바운드TM</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000091">고객상담·인바운드</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000093">CS관리·강의</a></dd>
# </dl>
# </div>
# <div class="listBx side">
# <dl>
# <dt><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;dutyCtgr=10016">IT·인터넷</a></dt>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000100">웹프로그래머</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000101">응용프로그래머</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000102">시스템프로그래머</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000096">DBA·데이터베이스</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000097">네트워크·서버·보안</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000098">웹기획·PM</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000099">웹마케팅</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000103">컨텐츠·사이트운영</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000104">HTML·퍼블리싱·UI개발</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000105">웹디자인</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000095">QA·테스터·검증</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000094">게임</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000106">ERP·시스템분석·설계</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000107">IT·디자인·컴퓨터강사</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000108">동영상제작·편집</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000109">빅데이터·AI(인공지능)</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000110">소프트웨어·하드웨어</a></dd>
# </dl>
# </div>
# <div class="listBx row02 begin">
# <dl>
# <dt><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;dutyCtgr=10018">연구개발·설계</a></dt>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000115">자동차·조선·기계</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000116">반도체·디스플레이</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000117">화학·에너지·환경</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000118">전기·전자·제어</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000119">기계설계·CAD·CAM</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000120">통신기술·네트워크구축</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000121">바이오·제약·식품</a></dd>
# </dl>
# </div>
# <div class="listBx row02">
# <dl>
# <dt><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;dutyCtgr=10021">건설</a></dt>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000141">건축·설계·인테리어</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000142">시공·현장·감리·공무</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000143">토목·조경·도시·측량</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000144">전기·소방·통신·안전</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000145">환경·플랜트</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000146">부동산·중개·분양·경매</a></dd>
# </dl>
# </div>
# <div class="listBx row02">
# <dl>
# <dt><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;dutyCtgr=10013">마케팅·광고·홍보</a></dt>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000071">마케팅·광고·분석</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000072">홍보·PR</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000073">전시·컨벤션</a></dd>
# </dl>
# </div>
# <div class="listBx row02">
# <dl>
# <dt><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;dutyCtgr=10017">생산·제조</a></dt>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000111">생산관리·공정관리·품질관리</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000112">생산·제조·설비·조립</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000113">포장·가공</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000114">섬유·의류·패션</a></dd>
# </dl>
# </div>
# <div class="listBx row03 begin">
# <dl>
# <dt><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;dutyCtgr=10024">의료</a></dt>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000165">의사·치과·한의사</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000167">약사·한약사·약무보조</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000168">간호사</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000169">간호조무사</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000170">의료기사</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000171">사무·원무·코디</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000166">수의사·수의간호</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000172">의료직기타</a></dd>
# </dl>
# </div>
# <div class="listBx row03">
# <dl>
# <dt><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;dutyCtgr=10014">무역·유통</a></dt>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000075">해외영업·무역영업</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000076">수출입·무역사무</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000080">구매·자재</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000081">상품기획·MD</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000074">유통·물류·재고</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000077">배송·택배·운송</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000079">운전·기사</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000078">화물·중장비</a></dd>
# </dl>
# </div>
# <div class="listBx row03">
# <dl>
# <dt><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;dutyCtgr=10019">디자인</a></dt>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000122">그래픽디자인·CG</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000123">출판·편집디자인</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000124">제품·산업디자인</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000125">캐릭터·애니메이션</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000126">광고·시각디자인</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000127">의류·패션·잡화디자인</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000128">전시·공간디자인</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000129">디자인기타</a></dd>
# </dl>
# </div>
# <div class="listBx row03">
# <dl>
# <dt><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;dutyCtgr=10023">교육</a></dt>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000156">유치원·보육교사</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000157">초중고·특수학교</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000158">대학교수·강사·행정직</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000159">보습학원·입시학원</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000160">학원상담·관리·운영</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000161">학습지·과외·방문교사</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000162">외국어교육</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000163">자격증·기술·전문교육</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000164">교재기획·교수설계</a></dd>
# </dl>
# </div>
# <div class="listBx row03">
# <dl>
# <dt><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;dutyCtgr=10022">서비스</a></dt>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000155">요리·영양·제과제빵·바리스타</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000147">설치·정비·A/S</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000149">시설·보안·경비·안전</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000152">레저·스포츠</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000151">여행·항공·숙박</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000148">뷰티·미용·애완</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000150">주차·세차·주유</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000153">청소·가사·육아</a></dd>
# <dd><a class="" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;duty=1000154">이벤트·웨딩·도우미</a></dd>
# </dl>
# </div>
# </div>
# </div>
# <!-- 직무 // -->
# <!-- // 산업 -->
# <div class="industrySec listArea">
# <h3 class="titIndustry"><button class="btnTabList" type="button"><span class="line l"></span><span class="spNav"><span class="txIr">산업</span></span><span class="line r"></span></button></h3>
# <div class="listRecent">
# <h4 class="titRecent">최근본</h4><ul class="subList dev-industry-item dev-rstn-item"></ul>
# </div>
# <div class="listWrap" id="devGnbIndustryLayreArea"></div>
# </div>
# <!-- 산업 // -->
# <!-- // 지역 -->
# <div class="localSec listArea">
# <h3 class="titLocal"><button class="btnTabList" type="button"><span class="spNav"><span class="txIr">지역</span></span></button></h3>
# <div class="listRecent">
# <h4 class="titRecent">최근본</h4><ul class="subList dev-local-item dev-rstn-item"></ul>
# </div>
# <div class="listWrap" id="devGnbLocalLayreArea"></div>
# </div>
# <!-- 지역 // -->
# <div class="lyCloseBtn">
# <button type="button"><span class="spGnb"></span><span class="skip">직무·지역 찾기 닫기</span></button>
# </div>
# </div>
# <div class="bg"></div>
# </div>
# <!-- 직무·지역 찾기 레이어 // -->
# </div>
# <!-- 직무·지역 찾기 // -->
# <div class="subSchLink">
# <a class="linkItem" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=search">
# <span class="spNav"><span class="txIr">상세검색</span></span>
# </a>
# </div>
# </div>
# <!-- // 배너 영역 -->
# <div class="headBann">
# <strong class="skip">잡코리아 주요 서비스</strong>
# <div class="headBannBtns" style="display: block;">
# <button class="btnBannPrev spGnb" type="button">이전</button>
# <button class="btnBannNext spGnb" type="button">다음</button>
# </div>
# <div class="bannBx">
# <!-- 첫번째 배너 클래스 on 삭제 -->
# <a class="on" href="https://www.albamon.com" target="_blank" title="새창 열림"><img alt="알바의 상식 albamon" height="57" src="https://i.jobkorea.kr/content/images/ver_1/gnb/bann/bann_alba.jpg?20200107" width="135"/></a>
# <a href="https://campusmon.jobkorea.co.kr" target="_blank" title="새창 열림"><img alt="공모전·박람회 CAMPUS MON" height="57" src="https://i.jobkorea.kr/content/images/ver_1/gnb/bann/bann_campus.png" width="135"/></a>
# <a href="https://www.gamejob.co.kr" target="_blank" title="새창 열림"><img alt="게임업계 채용정보 GAMEJOB" height="57" src="https://i.jobkorea.kr/content/images/ver_1/gnb/bann/bann_gamejob.png?20190712" width="135"/></a>
# </div>
# </div>
# <!-- 배너 영역 // -->
# </div>
# <!-- headInner // -->
# <div class="headNavBar" id="headNavBar">
# <div class="navInner">
# <!-- 전체보기 버튼 클릭시 active 클래스 추가 -->
# <div class="allArea">
# <h2 class="skip">전체서비스</h2>
# <button class="btnAllService" type="button"><span class="spGnb"><span class="txIr">전체서비스 열기</span></span></button>
# <!-- // 전체보기 레이어 -->
# <div class="lyNavArea" id="devGnbAllServiceMenu">
# <div class="lyNavWrap">
# <div class="lyNavInner side">
# <div class="lyRow row01">
# <div class="lyCol col4">
# <div class="colItem">
# <strong class="titArea"><a class="tit" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=local&amp;localorder=1">채용정보<span class="spGnb"></span></a></strong>
# <div class="listBx">
# <ul>
# <li><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=search">상세검색</a></li>
# <li><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=local&amp;localorder=1">지역별</a></li>
# <li><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty">직무별</a></li>
# <li><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=industry">산업별</a></li>
# <li><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=cotype1&amp;cotype=1,2,3">기업별</a></li>
# <li><a href="https://www.jobkorea.co.kr/Super/Main">슈퍼기업관</a></li>
# <li><a href="https://www.jobkorea.co.kr/Theme/Main">전문채용관</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="lyCol col4">
# <div class="colItem">
# <strong class="titArea"><a class="tit" href="https://www.jobkorea.co.kr/starter">공채<span class="spGnb"></span></a></strong>
# <div class="listBx">
# <ul>
# <li><a href="https://www.jobkorea.co.kr/starter/">1000대기업 공채</a></li>
# <li><a href="https://www.jobkorea.co.kr/starter/calendar/">공채달력</a></li>
# <li><a href="https://www.jobkorea.co.kr/starter/company/">기업공채전략</a></li>
# <li><a href="https://www.jobkorea.co.kr/starter/interview">직무인터뷰</a></li>
# <li><a href="https://www.jobkorea.co.kr/starter/jobfair/">채용설명회</a></li>
# <li><a href="https://www.jobkorea.co.kr/starter/spec/">합격스펙</a></li>
# <li><a href="https://www.jobkorea.co.kr/starter/passassay/">합격자소서</a></li>
# <li><a href="https://www.jobkorea.co.kr/starter/learning">취업특강</a></li>
# <li><a href="https://www.jobkorea.co.kr/starter/review/">인적성·면접후기</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="lyCol col4">
# <div class="colItem">
# <strong class="titArea"><a class="tit" href="https://www.jobkorea.co.kr/headhunting/home">헤드헌팅<span class="spGnb"></span></a></strong>
# <div class="listBx">
# <ul>
# <li><a href="https://www.jobkorea.co.kr/headhunting/home">헤드헌팅 채용정보</a></li>
# <li><a href="https://www.jobkorea.co.kr/headhunting/headhunter/">헤드헌터 찾기</a></li>
# <li><a href="https://www.jobkorea.co.kr/User/consulting">헤드헌팅 채용상담</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="lyCol col4">
# <div class="colItem">
# <strong class="titArea"><a class="tit" href="https://www.jobkorea.co.kr/Salary/">연봉<span class="spGnb"></span></a></strong>
# <div class="listBx">
# <ul>
# <li><a href="https://www.jobkorea.co.kr/Salary/">연봉통계</a></li>
# <li><a href="https://www.jobkorea.co.kr/Salary/?act=s&amp;el=salarySearchCompany">기업검색</a></li>
# <li><a href="https://www.jobkorea.co.kr/Salary/?act=s&amp;el=salaryNew">연봉뉴스</a></li>
# <li><a href="https://www.jobkorea.co.kr/Salary/MyList">내 연봉관리</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="lyRow row02">
# <div class="lyCol col4">
# <div class="colItem">
# <strong class="titArea"><a class="tit" href="https://www.jobkorea.co.kr/GoodJob/Tip">뉴스·자료<span class="spGnb"></span></a></strong>
# <div class="listBx">
# <ul>
# <li><a href="https://www.jobkorea.co.kr/GoodJob/Tip">취업뉴스</a></li>
# <li><a href="https://www.jobkorea.co.kr/GoodJob/Docs/form">자료실</a></li>
# <li><a href="https://www.jobkorea.co.kr/service/user/tool/spellcheck">취업 성공 툴</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="lyCol col4">
# <div class="colItem">
# <strong class="titArea"><a class="tit" href="https://www.jobkorea.co.kr/service/user/tool/spellcheck">취업 성공 툴<span class="spGnb"></span></a></strong>
# <div class="listBx">
# <ul>
# <li><a href="https://www.jobkorea.co.kr/SelfIntroduction/PassAssayIndex" target="_blank" title="새창 열림">자소서 작성<span class="icnNavBlank spGnb"></span></a></li>
# <li><a href="https://www.jobkorea.co.kr/service/user/tool/spellcheck">맞춤법 검사</a></li>
# <li><a href="https://www.jobkorea.co.kr/service/user/tool/textcount">글자수 세기</a></li>
# <li><a href="https://www.jobkorea.co.kr/service/user/tool/univpoint">학점계산기</a></li>
# <li><a href="https://www.jobkorea.co.kr/service/user/tool/engpoint">어학점수 변환</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="sideCol">
# <div class="sideInner">
# <div class="row01">
# <div class="sideList">
# <ul>
# <li class="ai"><a href="https://www.jobkorea.co.kr/AI/Analysis"><span class="spGnb icnList"></span>AI면접</a></li>
# <li class="qna"><a href="https://www.jobkorea.co.kr/user/qstn/Index"><span class="spGnb icnList"></span>취업톡톡</a></li>
# <li class="spec"><a href="https://www.jobkorea.co.kr/starter/spec/"><span class="spGnb icnList"></span>합격스펙</a></li>
# <li class="career"><a href="https://www.jobkorea.co.kr/careerpath/"><span class="spGnb icnList"></span>커리어패스</a></li>
# <li class="onair"><a href="https://www.jobkorea.co.kr/starter/onair"><span class="spGnb icnList"></span>잡코리아 TV</a></li>
# <li class="inside"><a href="https://www.jobkorea.co.kr/starter/companyreport/"><span class="spGnb icnList"></span>기업분석보고서</a></li>
# <li class="test"><a href="https://www.jobkorea.co.kr/starter/AptitudeTest/PubCoMockTest/"><span class="spGnb icnList"></span>공기업 모의고사</a></li>
# <!--<li class="option"><a href="https://www.jobkorea.co.kr/service/user/serviceguide"><span class="spGnb icnList"></span>서비스안내</a></li>-->
# </ul>
# </div>
# </div>
# <div class="row02">
# <div class="sideBtmBx">
# <div class="corpBx">
# <p class="tit">인재를 찾으시나요?</p>
# <p class="tx">채용공고를 등록하세요.</p>
# <div class="link"><a href="https://www.jobkorea.co.kr/Corp/Main">기업서비스<span class="spGnb"></span></a></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div></div>
# <!-- 전체보기 레이어 // -->
# </div>
# <div class="jkNavArea">
# <h2 class="skip">주요서비스</h2>
# <ul class="serviceNav">
# <!-- 메뉴 활성화 클래스 navFixed 마우스 오버시 active 클래스 추가 -->
# <li class="navItem gi" id="gnbGi">
# <a class="linkItem" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=local&amp;localorder=1"><span class="spNav"><span class="txIr">채용정보</span></span></a>
# <!-- // 채용정보 레이어 -->
# <div class="lyNavArea">
# <h3 class="skip">채용정보 세부메뉴</h3>
# <div class="lyNavWrap">
# <div class="lyNavInner side">
# <div class="lyRow row01">
# <div class="lyCol col4">
# <div class="colItem">
# <strong class="titArea">
# <a class="tit" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty">직무별<span class="spGnb"></span></a>
# </strong>
# <div class="listBx">
# <ul>
# <li><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;dutyCtgr=10012">경영·사무</a></li>
# <li><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;dutyCtgr=10013">마케팅·광고·홍보</a></li>
# <li><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;dutyCtgr=10016">IT·인터넷</a></li>
# <li><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;dutyCtgr=10019">디자인</a></li>
# <li><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;dutyCtgr=10014">무역·유통</a></li>
# <li><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;dutyCtgr=10015">영업·고객상담</a></li>
# <li><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;dutyCtgr=10022">서비스</a></li>
# <li><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;dutyCtgr=10018">연구개발·설계</a></li>
# <li><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;dutyCtgr=10017">생산·제조</a></li>
# <li><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;dutyCtgr=10023">교육</a></li>
# <li><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;dutyCtgr=10021">건설</a></li>
# <li><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;dutyCtgr=10024">의료</a></li>
# <li><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;dutyCtgr=10020">미디어</a></li>
# <li><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=duty&amp;dutyCtgr=10025">전문·특수직</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="lyCol col4">
# <div class="colItem">
# <strong class="titArea"><a class="tit" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=industry">산업별<span class="spGnb"></span></a></strong>
# <div class="listBx">
# <ul>
# <li><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=industry&amp;industryCtgr=10001">서비스업</a></li>
# <li><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=industry&amp;industryCtgr=10002">금융·은행업</a></li>
# <li><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=industry&amp;industryCtgr=10007">IT·정보통신업</a></li>
# <li><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=industry&amp;industryCtgr=10010">판매·유통업</a></li>
# <li><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=industry&amp;industryCtgr=10009">제조·생산·화학업</a></li>
# <li><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=industry&amp;industryCtgr=10011">교육업</a></li>
# <li><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=industry&amp;industryCtgr=10003">건설업</a></li>
# <li><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=industry&amp;industryCtgr=10004">의료·제약업</a></li>
# <li><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=industry&amp;industryCtgr=10005">미디어·광고업</a></li>
# <li><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=industry&amp;industryCtgr=10006">문화·예술·디자인업</a></li>
# <li><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=industry&amp;industryCtgr=10008">기관·협회</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="lyCol col4 row02">
# <div class="colItem">
# <strong class="titArea"><a class="tit" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=local&amp;localorder=1">지역별<span class="spGnb"></span></a></strong>
# <div class="listBx">
# <ul class="colList joblistArea">
# <li class="begin"><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=local&amp;local=I000">서울</a></li>
# <li class=""><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=local&amp;local=B000">경기</a></li>
# <li class=""><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=local&amp;local=K000">인천</a></li>
# <li class="begin"><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=local&amp;local=G000">대전</a></li>
# <li class=""><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=local&amp;local=1000">세종</a></li>
# <li class=""><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=local&amp;local=O000">충남</a></li>
# <li class="begin"><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=local&amp;local=P000">충북</a></li>
# <li class=""><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=local&amp;local=E000">광주</a></li>
# <li class=""><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=local&amp;local=L000">전남</a></li>
# <li class="begin"><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=local&amp;local=M000">전북</a></li>
# <li class=""><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=local&amp;local=F000">대구</a></li>
# <li class=""><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=local&amp;local=D000">경북</a></li>
# <li class="begin"><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=local&amp;local=H000">부산</a></li>
# <li class=""><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=local&amp;local=J000">울산</a></li>
# <li class=""><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=local&amp;local=C000">경남</a></li>
# <li class="begin"><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=local&amp;local=A000">강원</a></li>
# <li class=""><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=local&amp;local=N000">제주</a></li>
# <li class=""><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=local&amp;local=Q000">전국</a></li>
# </ul>
# </div>
# </div>
# <div class="colItem">
# <strong class="titArea"><a class="tit" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=edu3&amp;edu=3,4,5,6,7,8">학력별<span class="spGnb"></span></a></strong>
# <div class="listBx">
# <ul>
# <li><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=edu1&amp;edu=3">고졸채용</a></li>
# <li><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=edu2&amp;edu=4">대학(2,3년제) 채용</a></li>
# <li><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=edu3&amp;edu=5">대학교(4년제) 채용</a></li>
# <li><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=edu4&amp;edu=6,7">석박사 우대</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="lyCol col4 row02">
# <div class="colItem">
# <strong class="titArea"><a class="tit" href="https://www.jobkorea.co.kr/recruit/joblist?menucode=cotype1&amp;cotype=1,2,3">기업별<span class="spGnb"></span></a></strong>
# <div class="listBx">
# <ul>
# <li><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=cotype1&amp;cotype=1,2,3">대기업</a></li>
# <li><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=cotype2&amp;cotype=4,5">중견·강소기업</a></li>
# <li><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=cotype3&amp;cotype=6">외국계기업</a></li>
# <li><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=cotype4&amp;cotype=8">공기업·공사</a></li>
# <li><a href="https://www.jobkorea.co.kr/recruit/joblist?menucode=cotype5&amp;cotype=11,12,13,14">상장기업</a></li>
# <li><a href="https://www.jobkorea.co.kr/list_gi/csc/list.asp">공무원·공직</a></li>
# </ul>
# </div>
# </div>
# <div class="colItem">
# ...
#                 check: function () {
#                     if (typeof kakaoPixel === 'undefined') {
#                         console.log("kakaoPixel is not defined")
#                         return false;
#                     } else {
#                         return true;
#                     }
#                 },
#                 pageView: function () {
#                     if (self.method().check()) {
#                         self.method().console('pageView');
#                         kakaoPixel(self.key).pageView();
#                     }
#                 },
#                 completeRegistration: function () {
#                     if (self.method().check()) {
#                         self.method().console('completeRegistration');
#                         kakaoPixel(self.key).completeRegistration();
#                     }
#                 },
#                 participation: function () {
#                     if (self.method().check()) {
#                         self.method().console('participation');
#                         kakaoPixel(self.key).participation();
#                     }
#                 },
#                 purchase: function () {
#                     if (self.method().check()) {
#                         self.method().console('purchase');
#                         kakaoPixel(self.key).purchase();
#                     }
#                 },
#                 addToWishList: function () {
#                     if (self.method().check()) {
#                         self.method().console('addToWishList');
#                         kakaoPixel(self.key).addToWishList();
#                     }
#                 },
#                 addToCart: function () {
#                     if (self.method().check()) {
#                         self.method().console('addToCart');
#                         kakaoPixel(self.key).addToCart();
#                     }
#                 },
#                 console: function (eventStr) {
#                     //console.log('%c KakaoPixel %c load %c ' + eventStr, 'background: #4C5667;font-size: 12px;color: #FFF;padding: 6px;', 'background: #3474E8;font-size: 12px;color: #FFF;padding: 6px;', 'background: #027a00;font-size: 12px;color: #FFF;padding: 6px;');
#                 }
#             }
#         }
#     };
#
#
#     if (window.addEventListener) {
#         window.addEventListener('load', function () {
#             if (kakaoPixelTag !== 'undefined') {
#                 kakaoPixelTag.load();
#             }
#         });
#     }
# </script>
# <script>
# var jkcriteoEvt = {
#     el : $(document),
#     Criteo_Event : 'viewList',
#     CriteoMail: '',
#     gno : '',
#     gnolist: ["36710668","36719246","36680880"],
#     isload : false,
#     load: function () {
#         var self = this;
#         if (self.isload) {
#             self.event();
#         } else {
#             self.method().lazyloadScriptFn('//dynamic.criteo.com/js/ld/ld.js?a=87221', function () {
#                 self.isload = true;
#                 self.event();
#             });
#         }
#     },
#
#     event: function () {
#         var self = this;
#         console.log(self.Criteo_Event);
#         if (self.Criteo_Event == "viewHome") {
#             self.method().viewhome();
#         } else if (self.Criteo_Event == "trackTransaction") {
#             self.method().trackTransaction();
#         } else if (self.Criteo_Event == "viewList") {
#                         self.method().criteo_viewlist();
#
#         } else if (self.Criteo_Event == "viewPage") {
#             self.method().viewPage();
#         } else if (self.Criteo_Event == "viewItem") {
#             self.method().viewItem();
#         }
#     },
#     method: function () {
#         var self = this;
#
#         return {
#
#             lazyloadScriptFn : function(url, callback) {
#                 var scriptEle = document.createElement('script');
#                 scriptEle.type = 'text/javascript';
#                 var loaded = false;
#                 scriptEle.onreadystatechange = function () {
#                     // 서버에서 읽어올 경우 loaded, 캐쉬에서 가져올 경우 complete 이기에 둘 모두 처리
#                     if (this.readyState == 'loaded' || this.readyState == 'complete') {
#                         if (loaded) return;
#                         loaded = true;
#                         callback();
#                     }
#                 }
#                 scriptEle.onload = function () {
#                     callback();
#                 };
#                 scriptEle.src = url;
#                 document.getElementsByTagName('head')[0].appendChild(scriptEle);
#             },
#
#             joblistevt: function (className) {
#                 if (self.el.find(className).length == 0) {
#                     return;
#                 }
#                 var _len = self.el.find(className).length < 3 ? self.el.find(className).length : 3;
#                 self.gnolist = self.el.find(className).slice(0, _len).map(function () { return $(this).data('gno'); }).get();
#                 self.method().criteo_viewlist(self.Criteo_Event);
#             },
#
#             criteo_viewlist: function (pagetype) {
#                 window.criteo_q = window.criteo_q || [];
#                 if (self.gnolist.length > 0) {
#                     //console.log("%c criteo %c viewList " + self.gnolist + " gnoCount : " + self.gnolist.length, "background:orange; color: #FFF;font-size: 12px; padding:6px;", "background:green; color: #FFF;font-size: 12px; padding:6px;");
#                     window.criteo_q.push(
#                         { event: "setAccount", account: 87221 },
#                         { event: "setSiteType", type: "d" },
#                         { event: "viewList", item: self.gnolist }
#                     );
#                     self.gnolist = [];
#                 }
#             },
#
#             viewhome: function () {
#                 //console.log("%c criteo %c load Event = viewhome", "background:orange; color: #FFF;font-size: 12px; padding:6px;", "background:green; color: #FFF;font-size: 12px; padding:6px;");
#                 window.criteo_q = window.criteo_q || [];
#                 window.criteo_q.push(
#                     { event: "setAccount", account: 87221 },
#                     { event: "setSiteType", type: "d" },
#                     { event: "viewhome" }
#                 );
#             },
#
#             trackTransaction: function () {
#
#                 if (self.gno != '') {
#                     //console.log("%c criteo %c load Event = trackTransaction", "background:orange; color: #FFF;font-size: 12px; padding:6px;", "background:green; color: #FFF;font-size: 12px; padding:6px;");
#                     window.criteo_q = window.criteo_q || [];
#                     window.criteo_q.push(
#                         { event: "setAccount", account: 87221 },
#                         { event: "setSiteType", type: "d" },
#                         {
#                             event: "trackTransaction", id: '1638498503', deduplication: 1,
#                             item: [{ id: self.gno, price: 1, quantity: 1 }]
#                         }
#                     );
#                     self.gno = '';
#                 }
#             },
#
#             viewPage: function () {
#                 //console.log("%c criteo %c load Event = viewPage", "background:orange; color: #FFF;font-size: 12px; padding:6px;", "background:green; color: #FFF;font-size: 12px; padding:6px;");
#                 window.criteo_q = window.criteo_q || [];
#                 window.criteo_q.push(
#                     { event: "setAccount", account: 87221 },
#                     { event: "setSiteType", type: "d" },
#                     { event: "viewPage" }
#                 );
#             },
#
#             viewItem: function () {
#                 //console.log("%c criteo %c load Event = viewItem", "background:orange; color: #FFF;font-size: 12px; padding:6px;", "background:green; color: #FFF;font-size: 12px; padding:6px;");
#                 if (self.gno != "") {
#                     //console.log("%c criteo %c viewList " + self.gno, "background:orange; color: #FFF;font-size: 12px; padding:6px;", "background:green; color: #FFF;font-size: 12px; padding:6px;");
#                     window.criteo_q = window.criteo_q || [];
#                     window.criteo_q.push(
#                         { event: "setAccount", account: 87221 },
#                         { event: "setSiteType", type: "d" },
#                         { event: "viewItem", item: self.gno  }
#                     );
#                     self.gno = ''
#                 }
#             }
#
#         }
#     }
#     }
#     if (window.addEventListener) {
#         window.addEventListener('load', function () {
#             if (typeof jkcriteoEvt !== 'undefined') {
#                 jkcriteoEvt.load();
#             }
#         });
#     }
#     var criteo_viewlist = function (criteo_gnos, pagetype) {
#         //console.log("%c criteo %c load Event = viewlist 2", "background:orange; color: #FFF;font-size: 12px; padding:6px;", "background:green; color: #FFF;font-size: 12px; padding:6px;");
#         //console.log("criteo_viewlist : " + criteo_gnos + "/" + pagetype);
#         window.criteo_q = window.criteo_q || [];
#         window.criteo_q.push(
#                 { event: "setAccount", account: 87221 },
#                 { event: "setSiteType", type: "d" },
#                 { event: "viewList", item: [criteo_gnos] }
#         );
#     }
# </script>
# <script src="/Scripts/jquery-1.10.2.js"></script><ins class="adsbygoogle adsbygoogle-noablate" data-ad-status="unfilled" data-adsbygoogle-status="done" style="display: none !important;"><ins aria-label="Advertisement" id="aswift_0_expand" style="border: none; height: 0px; width: 0px; margin: 0px; padding: 0px; position: relative; visibility: visible; background-color: transparent; display: inline-table;" tabindex="0" title="Advertisement"><ins id="aswift_0_anchor" style="border: none; height: 0px; width: 0px; margin: 0px; padding: 0px; position: relative; visibility: visible; background-color: transparent; display: block;"><iframe allow="attribution-reporting" allowfullscreen="true" allowtransparency="true" data-google-container-id="a!1" data-load-complete="true" frameborder="0" hspace="0" id="aswift_0" marginheight="0" marginwidth="0" name="aswift_0" sandbox="allow-forms allow-popups allow-popups-to-escape-sandbox allow-same-origin allow-scripts allow-top-navigation-by-user-activation" scrolling="no" src="https://googleads.g.doubleclick.net/pagead/ads?client=ca-pub-2252464458280030&amp;output=html&amp;adk=1812271804&amp;adf=3025194257&amp;lmt=1638498018&amp;plat=3%3A32%2C4%3A32%2C9%3A32776%2C16%3A8388608%2C17%3A32%2C24%3A32%2C25%3A32%2C30%3A1081344%2C32%3A32&amp;format=0x0&amp;url=https%3A%2F%2Fwww.jobkorea.co.kr%2FTop100%2F%3FMain_Career_Type%3D1%26Search_Type%3D1%26BizJobtype_Bctgr_Code%3D10016%26BizJobtype_Bctgr_Name%3DIT%25C2%25B7%25EC%259D%25B8%25ED%2584%25B0%25EB%2584%25B7%26BizJobtype_Code%3D0%26BizJobtype_Name%3DIT%25C2%25B7%25EC%259D%25B8%25ED%2584%25B0%25EB%2584%25B7%2B%25EC%25A0%2584%25EC%25B2%25B4%26Major_Big_Code%3D0%26Major_Big_Name%3D%25EC%25A0%2584%25EC%25B2%25B4%26Major_Code%3D0%26Major_Name%3D%25EC%25A0%2584%25EC%25B2%25B4%26Edu_Level_Code%3D9%26Edu_Level_Name%3D%25EC%25A0%2584%25EC%25B2%25B4%26Edu_Level_Name%3D%25EC%25A0%2584%25EC%25B2%25B4%26MidScroll%3D0&amp;ea=0&amp;flash=0&amp;pra=5&amp;wgl=1&amp;uach=WyJtYWNPUyIsIjEyLjAuMSIsImFybSIsIiIsIjk2LjAuNDY2NC41NSIsW10sbnVsbCxudWxsLCI2NCJd&amp;dt=1638498017660&amp;bpp=11&amp;bdt=1321&amp;idt=557&amp;shv=r20211201&amp;mjsv=m202111170101&amp;ptt=9&amp;saldr=aa&amp;abxe=1&amp;nras=1&amp;correlator=8556076309384&amp;frm=20&amp;pv=2&amp;ga_vid=1586569473.1638498018&amp;ga_sid=1638498018&amp;ga_hid=2141905069&amp;ga_fc=0&amp;u_tz=540&amp;u_his=2&amp;u_h=1024&amp;u_w=1366&amp;u_ah=999&amp;u_aw=1366&amp;u_cd=24&amp;u_sd=2&amp;dmc=8&amp;adx=-12245933&amp;ady=-12245933&amp;biw=1361&amp;bih=801&amp;scr_x=0&amp;scr_y=0&amp;oid=2&amp;pvsid=1498240826780506&amp;pem=732&amp;tmod=160494657&amp;eae=2&amp;fc=1920&amp;brdim=5%2C-925%2C5%2C-925%2C1366%2C-999%2C1200%2C831%2C1361%2C801&amp;vis=1&amp;rsz=%7C%7Cs%7C&amp;abl=NS&amp;fu=32768&amp;bc=31&amp;ifi=1&amp;uci=a!1&amp;fsb=1&amp;dtd=605" style="left:0;position:absolute;top:0;border:0;width:undefinedpx;height:undefinedpx;" vspace="0"></iframe></ins></ins></ins>
# <script src="https://i.jobkorea.kr/content/js/jk_uit.js" type="text/javascript"></script>
# <script src="https://i.jobkorea.kr/content/javascript/pc/dist/top100/ui.top100.min.js" type="text/javascript"></script>
# <script src="https://i.jobkorea.kr/content/js/starter/jquery.nanoscroller.js" type="text/javascript"></script>
# <script src="/Scripts/Common/ServiceFunction.js?v=202112011400" type="text/javascript"></script>
# <script src="/Scripts/Top100/top100Default.js?v=202112011400" type="text/javascript"></script>
# <!--// 사이드 메뉴 UI 확인용 -->
# <script>
#         $(document).ready(function () {
#             var b = $(".quickLinkWrap").offset().top;
#             var c = $(".topContent").offset().top + $(".topContent").outerHeight();
#             var d = c - $(".quickLinkWrap").outerHeight();
#
#             function scrollAside() {
#                 var a = $(window).scrollTop();
#                 var $this = $(".quickLinkWrap");
#
#                 if (a <= b) {
#                     $this.removeClass("fixed");
#                 } else if (a >= d) {
#                     $this.addClass("fixed");
#                     $this.addClass("end");
#                 } else {
#                     $this.addClass("fixed");
#                     $this.removeClass("end");
#                 }
#             }
#
#             $(window).on("scroll load reload resize", function () {
#                 scrollAside();
#             });
#         });
#
#         $(window).load(function () {
#             $(".cols-depth2").css("display", "");
#             ui.top100.category.checkDepthScrolling();
#             $(".nano-content").scrollTop($("#MidScroll").val());
#         })
#
#         $('.btnSideTop .tplBtnTop').click(function () {
#             $('body,html').animate({
#                 scrollTop: 0
#             }, 500);
#         });
#     </script>
# <!-- UI 확인용 //-->
# <script>
#
#         // 상단 landing banner가 있을경우 실행할 함수(http://www.jobkorea.co.kr/List_GI/GI_Main.asp)
#         jkUitSideBar.landingBanner('.landingBannerSimple');
#
#         $(function () {
#             // sidebar ui 실행함수
#             jkUitSideBar.init();
#
#             // 레이어 ui확인용 실행함수 개발시 삭제해주세요
#             jQuery(document).on('click', '.titTotal .link', function (event) {
#                 jkSideBar.dataComplete();
#             })
#         });
#
#     </script>
# <iframe src="https://bid.g.doubleclick.net/xbbe/pixel?d=KAE" style="display: none;"></iframe><iframe height="0" src="https://www.google.com/recaptcha/api2/aframe" style="display: none;" width="0"></iframe><div id="criteo-tags-div" style="display: none;"><iframe frameborder="0" height="0" id="criteo-syncframe-onetag" src='https://gum.criteo.com/syncframe?topUrl=www.jobkorea.co.kr&amp;origin=onetag#{"bundle":{"origin":0,"value":null},"cw":true,"optout":{"origin":0,"value":null},"origin":"onetag","pm":0,"sid":{"origin":0,"value":null},"tld":"jobkorea.co.kr","topUrl":"www.jobkorea.co.kr","version":"5_8_0","ifa":{"origin":0,"value":null},"lsw":true}' style="border-width:0px; margin:0px; display:none" title="Criteo GUM iframe" width="0"></iframe><script async="true" src="https://sslwidget.criteo.com/event?a=87221&amp;v=5.8.0&amp;p0=e%3Dexd%26site_type%3Dd&amp;p1=e%3Dvl%26p%3D%255B36710668%252C36719246%252C36680880%255D&amp;p2=e%3Ddis&amp;adce=1&amp;bundle=&amp;tld=jobkorea.co.kr&amp;dy=1&amp;dtycbr=93506" type="text/javascript"></script></div><iframe height="0" style="display: none;" title="Criteo DIS iframe" width="0"></iframe></body><iframe id="google_esf" name="google_esf" src="https://googleads.g.doubleclick.net/pagead/html/r20211201/r20190131/zrt_lookup.html" style="display: none;"></iframe></html>

# %%
rank_rookie = []

for tag in soup.select('#devTypeTab_1 > div.rankListWrap > div.rankListArea.devSarterTab > ol > li '):
    company = {}    
    company['rank'] = tag.select('div > span.num')[0].text
    company['company'] = tag.select('div.co > div.coTit > a')[0].text
    company['title'] = tag.select('div.info > div.tit')[0].text
    company['duty'] = tag.select('div.info > div.sTit')[0].text
    company['career'] = tag.select('div.info > div.sDsc > span')[0].text
    company['degree'] = tag.select('div.info > div.sDsc > span')[1].text
    company['work_place'] = tag.select('div.info > div.sDsc > span')[2].text
    company['work_type'] = tag.select('div.info > div.sDsc > span')[3].text

    company['due_date'] = tag.select('div.side > span.day')[0].text
    
    rank_rookie.append(company)
    
rank_rookie
# Out:
# [{'rank': '1',
#   'company': '㈜비상교육',
#   'title': '\n\n\n\n스크랩\n\n\n\n12월 각 부문별 경력 및 신입 채용\n',
#   'duty': '\n동영상제작·편집\n웹프로그래머\n응용프로그래머\n시스템프로그래머 외\n',
#   'career': '신입·경력',
#   'degree': '학력무관',
#   'work_place': '서울, 경기',
#   'work_type': '정규직',
#   'due_date': '~12/25(토)'},
#  {'rank': '2',
#   'company': '㈜한익스프레스',
#   'title': '\n\n\n\n스크랩\n\n\n\n2022년도 경력 및 신입사원 공개모집\n',
#   'duty': '\n웹마케팅\n기획·전략·경영\n경리·회계·결산\n해외영업·무역영업 외\n',
#   'career': '신입·경력',
#   'degree': '대졸↑',
#   'work_place': '서울, 경기, 인천 외',
#   'work_type': '정규직',
#   'due_date': '~12/15(수)'},
#  {'rank': '3',
#   'company': '동아출판㈜',
#   'title': '\n\n\n\n스크랩\n\n\n\n2021년 하반기 신입(인턴) 및 경력사원 모집\n',
#   'duty': '\n웹기획·PM\n웹마케팅\n웹디자인\n동영상제작·편집 외\n',
#   'career': '인턴·신입·경력',
#   'degree': '초대졸↑',
#   'work_place': '서울',
#   'work_type': '정규직, 계약직 외',
#   'due_date': '~12/12(일)'},
#  {'rank': '4',
#   'company': '한미헬스케어㈜',
#   'title': '\n\n\n\n스크랩\n\n\n\n2021년 12월 수시채용\n',
#   'duty': '\n응용프로그래머\n시스템프로그래머\n컨텐츠·사이트운영\nDBA·데이터베이스 외\n',
#   'career': '신입·경력',
#   'degree': '초대졸↑',
#   'work_place': '서울, 경기, 인천',
#   'work_type': '정규직',
#   'due_date': '~12/19(일)'},
#  {'rank': '5',
#   'company': 'Naver I&S㈜',
#   'title': '\n\n\n\n스크랩\n\n\n\nNaver I&S㈜ 및 자회사 각 부문 신입/경력 수시 채용\n',
#   'duty': '\n웹디자인\n웹프로그래머\nHTML·퍼블리싱·UI개발\n경리·회계·결산 외\n',
#   'career': '신입·경력',
#   'degree': '학력무관',
#   'work_place': '경기, 인천, 강원',
#   'work_type': '정규직',
#   'due_date': '채용 시 마감'},
#  {'rank': '6',
#   'company': '㈜우아한형제들',
#   'title': '\n\n\n\n스크랩\n\n\n\n각 부문별 경력/신입 인재영입\n',
#   'duty': '\n응용프로그래머\n빅데이터·AI(인공지능)\n웹프로그래머\n시스템프로그래머 외\n',
#   'career': '신입·경력',
#   'degree': '학력무관',
#   'work_place': '서울',
#   'work_type': '정규직, 계약직',
#   'due_date': '~05/18(수)'},
#  {'rank': '7',
#   'company': '㈜아이비케이시스템',
#   'title': '\n\n\n\n스크랩\n\n\n\nIBK시스템 직원 모집\n',
#   'duty': '\n웹프로그래머\n응용프로그래머\n시스템프로그래머\nDBA·데이터베이스 외\n',
#   'career': '신입·경력',
#   'degree': '학력무관',
#   'work_place': '서울, 경기, 인천',
#   'work_type': '정규직',
#   'due_date': '~12/15(수)'},
#  {'rank': '8',
#   'company': '로젠㈜',
#   'title': '\n\n\n\n스크랩\n\n\n\n22년도 로젠㈜ 상반기 공개채용\n',
#   'duty': '\n응용프로그래머\n웹프로그래머\nDBA·데이터베이스\n웹기획·PM 외\n',
#   'career': '신입·경력',
#   'degree': '고졸↑',
#   'work_place': '서울, 경기, 대전 외',
#   'work_type': '정규직',
#   'due_date': '오늘마감'},
#  {'rank': '9',
#   'company': 'SPC삼립',
#   'title': '\n\n\n\n스크랩\n\n\n\n각 부문 신입/경력직 모집 (IR/마케팅/연구/영업/SCM/공무/품질관리)\n',
#   'duty': '\n웹기획·PM\n웹마케팅\n컨텐츠·사이트운영\n사무·총무·법무 외\n',
#   'career': '신입·경력',
#   'degree': '학력무관',
#   'work_place': '서울, 경기, 인천 외',
#   'work_type': '정규직',
#   'due_date': '~12/06(월)'},
#  {'rank': '10',
#   'company': 'KBS미디어㈜',
#   'title': '\n\n\n\n스크랩\n\n\n\nKBS미디어 공개채용\n',
#   'duty': '\n웹기획·PM\n웹마케팅\n컨텐츠·사이트운영\n동영상제작·편집 외\n',
#   'career': '신입·경력',
#   'degree': '학력무관',
#   'work_place': '서울',
#   'work_type': '계약직',
#   'due_date': '~12/08(수)'}]

# %%
rank_rookie
# Out:
# [{'rank': '1',
#   'company': '㈜비상교육',
#   'title': '\n\n\n\n스크랩\n\n\n\n12월 각 부문별 경력 및 신입 채용\n',
#   'duty': '\n동영상제작·편집\n웹프로그래머\n응용프로그래머\n시스템프로그래머 외\n',
#   'career': '신입·경력',
#   'degree': '학력무관',
#   'work_place': '서울, 경기',
#   'work_type': '정규직',
#   'due_date': '~12/25(토)'},
#  {'rank': '2',
#   'company': '㈜한익스프레스',
#   'title': '\n\n\n\n스크랩\n\n\n\n2022년도 경력 및 신입사원 공개모집\n',
#   'duty': '\n웹마케팅\n기획·전략·경영\n경리·회계·결산\n해외영업·무역영업 외\n',
#   'career': '신입·경력',
#   'degree': '대졸↑',
#   'work_place': '서울, 경기, 인천 외',
#   'work_type': '정규직',
#   'due_date': '~12/15(수)'},
#  {'rank': '3',
#   'company': '동아출판㈜',
#   'title': '\n\n\n\n스크랩\n\n\n\n2021년 하반기 신입(인턴) 및 경력사원 모집\n',
#   'duty': '\n웹기획·PM\n웹마케팅\n웹디자인\n동영상제작·편집 외\n',
#   'career': '인턴·신입·경력',
#   'degree': '초대졸↑',
#   'work_place': '서울',
#   'work_type': '정규직, 계약직 외',
#   'due_date': '~12/12(일)'},
#  {'rank': '4',
#   'company': '한미헬스케어㈜',
#   'title': '\n\n\n\n스크랩\n\n\n\n2021년 12월 수시채용\n',
#   'duty': '\n응용프로그래머\n시스템프로그래머\n컨텐츠·사이트운영\nDBA·데이터베이스 외\n',
#   'career': '신입·경력',
#   'degree': '초대졸↑',
#   'work_place': '서울, 경기, 인천',
#   'work_type': '정규직',
#   'due_date': '~12/19(일)'},
#  {'rank': '5',
#   'company': 'Naver I&S㈜',
#   'title': '\n\n\n\n스크랩\n\n\n\nNaver I&S㈜ 및 자회사 각 부문 신입/경력 수시 채용\n',
#   'duty': '\n웹디자인\n웹프로그래머\nHTML·퍼블리싱·UI개발\n경리·회계·결산 외\n',
#   'career': '신입·경력',
#   'degree': '학력무관',
#   'work_place': '경기, 인천, 강원',
#   'work_type': '정규직',
#   'due_date': '채용 시 마감'},
#  {'rank': '6',
#   'company': '㈜우아한형제들',
#   'title': '\n\n\n\n스크랩\n\n\n\n각 부문별 경력/신입 인재영입\n',
#   'duty': '\n응용프로그래머\n빅데이터·AI(인공지능)\n웹프로그래머\n시스템프로그래머 외\n',
#   'career': '신입·경력',
#   'degree': '학력무관',
#   'work_place': '서울',
#   'work_type': '정규직, 계약직',
#   'due_date': '~05/18(수)'},
#  {'rank': '7',
#   'company': '㈜아이비케이시스템',
#   'title': '\n\n\n\n스크랩\n\n\n\nIBK시스템 직원 모집\n',
#   'duty': '\n웹프로그래머\n응용프로그래머\n시스템프로그래머\nDBA·데이터베이스 외\n',
#   'career': '신입·경력',
#   'degree': '학력무관',
#   'work_place': '서울, 경기, 인천',
#   'work_type': '정규직',
#   'due_date': '~12/15(수)'},
#  {'rank': '8',
#   'company': '로젠㈜',
#   'title': '\n\n\n\n스크랩\n\n\n\n22년도 로젠㈜ 상반기 공개채용\n',
#   'duty': '\n응용프로그래머\n웹프로그래머\nDBA·데이터베이스\n웹기획·PM 외\n',
#   'career': '신입·경력',
#   'degree': '고졸↑',
#   'work_place': '서울, 경기, 대전 외',
#   'work_type': '정규직',
#   'due_date': '오늘마감'},
#  {'rank': '9',
#   'company': 'SPC삼립',
#   'title': '\n\n\n\n스크랩\n\n\n\n각 부문 신입/경력직 모집 (IR/마케팅/연구/영업/SCM/공무/품질관리)\n',
#   'duty': '\n웹기획·PM\n웹마케팅\n컨텐츠·사이트운영\n사무·총무·법무 외\n',
#   'career': '신입·경력',
#   'degree': '학력무관',
#   'work_place': '서울, 경기, 인천 외',
#   'work_type': '정규직',
#   'due_date': '~12/06(월)'},
#  {'rank': '10',
#   'company': 'KBS미디어㈜',
#   'title': '\n\n\n\n스크랩\n\n\n\nKBS미디어 공개채용\n',
#   'duty': '\n웹기획·PM\n웹마케팅\n컨텐츠·사이트운영\n동영상제작·편집 외\n',
#   'career': '신입·경력',
#   'degree': '학력무관',
#   'work_place': '서울',
#   'work_type': '계약직',
#   'due_date': '~12/08(수)'}]

# %% [markdown]
# # Senior

# %% [markdown]
# # 경력자 페이지 이동 안됨 -> 잡코리아 일안함

# %%
df = pd.DataFrame(rank_rookie)
df.head()
# Out:
#   rank     company                                              title  \
# 0    1       ㈜비상교육          \n\n\n\n스크랩\n\n\n\n12월 각 부문별 경력 및 신입 채용\n
# 1    2     ㈜한익스프레스         \n\n\n\n스크랩\n\n\n\n2022년도 경력 및 신입사원 공개모집\n
# 2    3       동아출판㈜    \n\n\n\n스크랩\n\n\n\n2021년 하반기 신입(인턴) 및 경력사원 모집\n
# 3    4     한미헬스케어㈜                \n\n\n\n스크랩\n\n\n\n2021년 12월 수시채용\n
# 4    5  Naver I&S㈜  \n\n\n\n스크랩\n\n\n\nNaver I&S㈜ 및 자회사 각 부문 신입/경력...
#
#                                              duty    career degree  \
# 0       \n동영상제작·편집\n웹프로그래머\n응용프로그래머\n시스템프로그래머 외\n     신입·경력   학력무관
# 1       \n웹마케팅\n기획·전략·경영\n경리·회계·결산\n해외영업·무역영업 외\n     신입·경력    대졸↑
# 2              \n웹기획·PM\n웹마케팅\n웹디자인\n동영상제작·편집 외\n  인턴·신입·경력   초대졸↑
# 3  \n응용프로그래머\n시스템프로그래머\n컨텐츠·사이트운영\nDBA·데이터베이스 외\n     신입·경력   초대졸↑
# 4    \n웹디자인\n웹프로그래머\nHTML·퍼블리싱·UI개발\n경리·회계·결산 외\n     신입·경력   학력무관
#
#      work_place   work_type   due_date
# 0        서울, 경기         정규직  ~12/25(토)
# 1  서울, 경기, 인천 외         정규직  ~12/15(수)
# 2            서울  정규직, 계약직 외  ~12/12(일)
# 3    서울, 경기, 인천         정규직  ~12/19(일)
# 4    경기, 인천, 강원         정규직    채용 시 마감

# %%
df = df.replace('\n', '', regex=True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/mh/q1r71q296q7grz41z51vbp6w0000gq/T/ipykernel_68381/1214151109.py in <module>
# ----> 1 df = df.replace('\n', '', regex=True)
#       2 df.head()
#
# NameError: name 'df' is not defined

# %%
df.to_csv('rank_rookie.csv', encoding='utf8')

# %%
# csv 파일 읽기

df = pd.read_csv('/Users/sky/class_python/1.Basic_crawling/rank_rookie_jobkorea.csv', index_col=0, encoding='utf-8')
df.head()
# Out:
#    rank     company                                 title  \
# 0     1       ㈜비상교육               스크랩12월 각 부문별 경력 및 신입 채용
# 1     2     ㈜한익스프레스              스크랩2022년도 경력 및 신입사원 공개모집
# 2     3       동아출판㈜         스크랩2021년 하반기 신입(인턴) 및 경력사원 모집
# 3     4     한미헬스케어㈜                     스크랩2021년 12월 수시채용
# 4     5  Naver I&S㈜  스크랩Naver I&S㈜ 및 자회사 각 부문 신입/경력 수시 채용
#
#                                    duty    career degree    work_place  \
# 0       동영상제작·편집웹프로그래머응용프로그래머시스템프로그래머 외     신입·경력   학력무관        서울, 경기
# 1       웹마케팅기획·전략·경영경리·회계·결산해외영업·무역영업 외     신입·경력    대졸↑  서울, 경기, 인천 외
# 2              웹기획·PM웹마케팅웹디자인동영상제작·편집 외  인턴·신입·경력   초대졸↑            서울
# 3  응용프로그래머시스템프로그래머컨텐츠·사이트운영DBA·데이터베이스 외     신입·경력   초대졸↑    서울, 경기, 인천
# 4    웹디자인웹프로그래머HTML·퍼블리싱·UI개발경리·회계·결산 외     신입·경력   학력무관    경기, 인천, 강원
#
#     work_type   due_date
# 0         정규직  ~12/25(토)
# 1         정규직  ~12/15(수)
# 2  정규직, 계약직 외  ~12/12(일)
# 3         정규직  ~12/19(일)
# 4         정규직    채용 시 마감

# %%
df.drop(['rank'],axis=1, inplace=True)
df.head()
# Out:
#       company                                 title  \
# 0       ㈜비상교육               스크랩12월 각 부문별 경력 및 신입 채용
# 1     ㈜한익스프레스              스크랩2022년도 경력 및 신입사원 공개모집
# 2       동아출판㈜         스크랩2021년 하반기 신입(인턴) 및 경력사원 모집
# 3     한미헬스케어㈜                     스크랩2021년 12월 수시채용
# 4  Naver I&S㈜  스크랩Naver I&S㈜ 및 자회사 각 부문 신입/경력 수시 채용
#
#                                    duty    career degree    work_place  \
# 0       동영상제작·편집웹프로그래머응용프로그래머시스템프로그래머 외     신입·경력   학력무관        서울, 경기
# 1       웹마케팅기획·전략·경영경리·회계·결산해외영업·무역영업 외     신입·경력    대졸↑  서울, 경기, 인천 외
# 2              웹기획·PM웹마케팅웹디자인동영상제작·편집 외  인턴·신입·경력   초대졸↑            서울
# 3  응용프로그래머시스템프로그래머컨텐츠·사이트운영DBA·데이터베이스 외     신입·경력   초대졸↑    서울, 경기, 인천
# 4    웹디자인웹프로그래머HTML·퍼블리싱·UI개발경리·회계·결산 외     신입·경력   학력무관    경기, 인천, 강원
#
#     work_type   due_date
# 0         정규직  ~12/25(토)
# 1         정규직  ~12/15(수)
# 2  정규직, 계약직 외  ~12/12(일)
# 3         정규직  ~12/19(일)
# 4         정규직    채용 시 마감

# %%
df = df.replace('스크랩', '', regex=True)
df.head()
# Out:
#       company                              title  \
# 0       ㈜비상교육               12월 각 부문별 경력 및 신입 채용
# 1     ㈜한익스프레스              2022년도 경력 및 신입사원 공개모집
# 2       동아출판㈜         2021년 하반기 신입(인턴) 및 경력사원 모집
# 3     한미헬스케어㈜                     2021년 12월 수시채용
# 4  Naver I&S㈜  Naver I&S㈜ 및 자회사 각 부문 신입/경력 수시 채용
#
#                                    duty    career degree    work_place  \
# 0       동영상제작·편집웹프로그래머응용프로그래머시스템프로그래머 외     신입·경력   학력무관        서울, 경기
# 1       웹마케팅기획·전략·경영경리·회계·결산해외영업·무역영업 외     신입·경력    대졸↑  서울, 경기, 인천 외
# 2              웹기획·PM웹마케팅웹디자인동영상제작·편집 외  인턴·신입·경력   초대졸↑            서울
# 3  응용프로그래머시스템프로그래머컨텐츠·사이트운영DBA·데이터베이스 외     신입·경력   초대졸↑    서울, 경기, 인천
# 4    웹디자인웹프로그래머HTML·퍼블리싱·UI개발경리·회계·결산 외     신입·경력   학력무관    경기, 인천, 강원
#
#     work_type   due_date
# 0         정규직  ~12/25(토)
# 1         정규직  ~12/15(수)
# 2  정규직, 계약직 외  ~12/12(일)
# 3         정규직  ~12/19(일)
# 4         정규직    채용 시 마감

# %%
df.to_csv('rank_rookie_jobkorea.csv', encoding='utf8')

# %%
import pymysql
import pandas as pd

# %%
# 데이터 읽어서 DB에 저장

# DB연동
conn = pymysql.connect(host='localhost',
                       database='jobkorea', # 자기 데이터 베이스에 맞게 접속
                       user='root',
                       passwd='mlb10200', #자기 비밀번호
                       charset='utf8',
                       local_infile=1) #혹시나 안되면 이거 켜서 접속

cursor = conn.cursor()

value_list = []
for index, row in rank_rookie.iterrows():
    tu = ( row.rank, row.company, row.title, row.duty,
          row.career, row.degree, row.work_place, row.work_type, 
          row.due_date ) 
    value_list.append(tu)
    
cursor.executemany('''
                  INSERT INTO jobkoreaDB (rank, company, title, duty, career, degree, work_place, work_type, due_date)
                  values ( %s, %s, %s, %s, %s, %s, %s, %s, %s )
                  ''', value_list)

conn.commit()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# /var/folders/mh/q1r71q296q7grz41z51vbp6w0000gq/T/ipykernel_65644/2024877931.py in <module>
#      18     value_list.append(tu)
#      19
# ---> 20 cursor.executemany('''
#      21                   INSERT INTO jobkoreaDB (rank, company, title, duty, career, degree, work_place, work_type, due_date)
#      22                   values ( %s, %s, %s, %s, %s, %s, %s, %s, %s )
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pymysql/cursors.py in executemany(self, query, args)
#     171             q_postfix = m.group(3) or ""
#     172             assert q_values[0] == "(" and q_values[-1] == ")"
# --> 173             return self._do_execute_many(
#     174                 q_prefix,
#     175                 q_values,
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pymysql/cursors.py in _do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     209                 sql += b","
#     210             sql += v
# --> 211         rows += self.execute(sql + postfix)
#     212         self.rowcount = rows
#     213         return rows
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pymysql/cursors.py in execute(self, query, args)
#     146         query = self.mogrify(query, args)
#     147
# --> 148         result = self._query(query)
#     149         self._executed = query
#     150         return result
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pymysql/cursors.py in _query(self, q)
#     308         self._last_executed = q
#     309         self._clear_result()
# --> 310         conn.query(q)
#     311         self._do_get_result()
#     312         return self.rowcount
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     546             sql = sql.encode(self.encoding, "surrogateescape")
#     547         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549         return self._affected_rows
#     550
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#     773         else:
#     774             result = MySQLResult(self)
# --> 775             result.read()
#     776         self._result = result
#     777         if result.server_status is not None:
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pymysql/connections.py in read(self)
#    1154     def read(self):
#    1155         try:
# -> 1156             first_packet = self.connection._read_packet()
#    1157
#    1158             if first_packet.is_ok_packet():
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     723             if self._result is not None and self._result.unbuffered_active is True:
#     724                 self._result.unbuffered_active = False
# --> 725             packet.raise_for_error()
#     726         return packet
#     727
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pymysql/protocol.py in raise_for_error(self)
#     219         if DEBUG:
#     220             print("errno =", errno)
# --> 221         err.raise_mysql_exception(self._data)
#     222
#     223     def dump(self):
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     141     if errorclass is None:
#     142         errorclass = InternalError if errno < 1000 else OperationalError
# --> 143     raise errorclass(errno, errval)
#
# ProgrammingError: (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'rank, company, title, duty, career, degree, work_place, work_type, due_date)\n   ' at line 1")
