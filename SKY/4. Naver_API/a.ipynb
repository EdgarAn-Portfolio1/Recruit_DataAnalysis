# %% [markdown]
# # https://developers.naver.com/docs/serviceapi/search/news/news.md#뉴스

# %% [markdown]
# # display 최대100 (한 요청당이 겠지)
# # 모듈화 라는거 하면 더 빨리 긁을수 있을지도

# %% [markdown]
# # ' 취업 "개발자" ': 22,000
# # '개발자' : 470,000

# %%
import os
import sys
import urllib.request

client_id = "mNhJ01jj6_6mlvwLR3uy" # 개발자센터에서 발급받은 Client ID 값
client_secret = "JAHWSRUs2D" # 개발자센터에서 발급받은 Client Secret 값
encText = urllib.parse.quote('개발자')
url = "https://openapi.naver.com/v1/search/news.json?query=" + encText +'&display=100&start=1&sort=date'
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Thu, 02 Dec 2021 00:44:11 +0900",
# "total": 471038,
# "start": 1,
# "display": 100,
# "items": [
# {
# "title": "두산디지털이노베이션, NFT 사업 진출…프로야구 NFT 상품 출시",
# "originallink": "http://apnews.kr/View.aspx?No=2133963",
# "link": "http://apnews.kr/View.aspx?No=2133963",
# "description": "플로우는 다목적 아키텍쳐, 리소스 지향 프로그래밍, <b>개발자</b> 인체 공학 등 6가지의 혁신적 기술을 보유하고 있다. 덕분에 원활한 지원과 높은 호환성, 편리한 사용자 경험, 안전하고 빠른 속도를 제공한다.... ",
# "pubDate": "Thu, 02 Dec 2021 00:30:00 +0900"
#
# },
# {
# "title": "[노트북을 열며] 서바이벌보다 성장",
# "originallink": "https://www.joongang.co.kr/article/25028700",
# "link": "https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=110&oid=025&aid=0003155489",
# "description": "네카라쿠배(네이버·카카오·라인·쿠팡·배달의민족)에 <b>개발자</b>로 입사하기 위해 고시공부하듯 하는 사람들이다. 이들은 컴퓨터 프로그래밍 입문과정부터 배우더라도, IT 대기업으로 이직하는 게 ‘성장’이자 ‘성공’... ",
# "pubDate": "Thu, 02 Dec 2021 00:20:00 +0900"
#
# },
# {
# "title": "[제20대 대선]'이재명의 민주당' 文정부와 정책 차별화",
# ...

# %%
import pandas as pd
import json

news = json.loads(response_body) # dict로 변경

print( news['items'][0]['title'] )

a = pd.DataFrame( news['items'] )
# Out:
# 청년실업·교육격차 해소 앞장… 미래인재 키우는 삼성 [2021 사회공헌대상]

# %%
print(len(a))
print(type(a))
a.head(5)

#link는 네이버에서 제공하는 링크임 ㅇㅅㅇ
# Out:
# 100
# <class 'pandas.core.frame.DataFrame'>
#                                                title  \
# 0         청년실업·교육격차 해소 앞장… 미래인재 키우는 삼성 [2021 사회공헌대상]
# 1                  [ET] 신용등급보다 중요한 ‘평판등급’…성공적 이직 비결은
# 2       애니파이브 김태형 연구소장, AI 기술기반 툴 앞세워 '제2의 캐시카우' 만든다
# 3  이젠아카데미컴퓨터학원, <b>취업</b> 경쟁력 갖춘 'UIUX 웹디자인·모바일(앱...
# 4                  “2030, 기성세대 무능함에 피해”…李 ‘또’ 청년층 구애
#
#                                         originallink  \
# 0      http://www.fnnews.com/news/202112011944125393
# 1  https://news.kbs.co.kr/news/view.do?ncd=533838...
# 2               http://www.etnews.com/20211201000146
# 3  http://www.lecturernews.com/news/articleView.h...
# 4  http://www.edaily.co.kr/news/newspath.asp?news...
#
#                                                 link  \
# 0  https://news.naver.com/main/read.naver?mode=LS...
# 1  https://news.naver.com/main/read.naver?mode=LS...
# 2  https://news.naver.com/main/read.naver?mode=LS...
# 3  http://www.lecturernews.com/news/articleView.h...
# ...
