# %%
import pymysql
import pandas as pd

# %%
# # DB연동
# conn = pymysql.connect(host='localhost',
#                        database='shakeit', # 자기 데이터 베이스에 맞게 접속
#                        user='root',
#                        passwd='mysql', #자기 비밀번호
#                        charset='utf8',
#                        local_infile=1) #혹시나 안되면 이거 켜서 접속

# cursor = conn.cursor()

# %%
#DB생성
#cursor.execute('create database jobkorea')

# %%
#TABLE 생성
# sql = '''
#     CREATE TABLE helpmeDB(
#         resource varchar(50),
#         company varchar(255),
#         duty varchar(255),
#         career varchar(255),
#         degree varchar(255),
#         work_place varchar(255),
#         work_type varchar(255),
#         category longtext,
#         link varchar(255),
#         info varchar(255)
#     )
#       '''
# cursor.execute(sql)
# 커밋필수
# conn.commit()

# %%
# #TABLE 삭제 문제 있을 때만 사용

# sql_drop = '''
#             DROP TABLE helpmeDB
# '''
# cursor.execute(sql_drop)
# conn.commit()

# %%
# csv 파일 읽기

recruit_info = pd.read_csv('C:/Users/user/Desktop/kdigital/final-project/data-files/jobkorea_saramin_recruit.csv', index_col=0, encoding='utf8')
recruit_info.head()
# Out:
#    resource     company                            duty career degree  \
# 0  jobkorea  디휴브(DEHUV)                  [디휴브] 개발자 부문채용  신입·경력   학력무관
# 1  jobkorea    ㈜레미유코스메틱   브랜드 디자이너 / MD / (카페)쇼룸 매니저 채용     경력   학력무관
# 2  jobkorea         ㈜순진        마케팅 담당자 및 상품기획/MD 경력직 채용  경력2년↑    고졸↑
# 3  jobkorea    효성에프엠에스㈜  2021년 효성에프엠에스 신입사원 및 경력사원 공개채용  신입·경력    대졸↑
# 4  jobkorea      ㈜빗썸코리아               빗썸코리아 부문별 경력사원 채용     경력   학력무관
#
#   work_place                work_type  \
# 0     경기 고양시                      정규직
# 1     서울 성동구  정규직                 외\n
# 2     서울 광진구                      정규직
# 3     서울 강남구                      정규직
# 4     서울 강남구                      정규직
#
#                                             category  \
# 0  ['반응형 웹, 백엔드, 풀스택, 하이브리드 앱, 소프트웨어개발, BigData, ...
# 1  ['화장품, 마케팅, 마케팅기획, 브랜딩, 프로모션, 상품기획, 신상품개발, 온라인...
# 2  ['영상편집, 포토샵, 제품기획, 광고기획, 마케팅, 마케팅기획, 바이럴마케팅, 브...
# 3  ['Jira, Spring Framework, 모바일앱개발, 소프트웨어개발, 솔루션...
# 4  ['기획, 기획조사, 사업기획, 사업제휴, 서비스기획, 전략, 법무, 송무, 인허가...
#
#                                                 link  \
# 0  https://www.jobkorea.co.kr/Recruit/GI_Read/366...
# 1  https://www.jobkorea.co.kr/Recruit/GI_Read/366...
# 2  https://www.jobkorea.co.kr/Recruit/GI_Read/366...
# 3  https://www.jobkorea.co.kr/Recruit/GI_Read/366...
# 4  https://www.jobkorea.co.kr/Recruit/GI_Read/366...
#
#                                                 info
# 0  https://www.jobkorea.co.kr/Recruit/Co_Read/C/d...
# 1  https://www.jobkorea.co.kr/Recruit/Co_Read/C/l...
# 2  https://www.jobkorea.co.kr/Recruit/Co_Read/C/s...
# 3  https://www.jobkorea.co.kr/Recruit/Co_Read/C/h...
# 4  https://www.jobkorea.co.kr/Recruit/Co_Read/C/b...

# %%
# recruit_info.reset_index(inplace=True)

# %%
# recruit_info.head()
# recruit_info['number'] = recruit_info['number'] + 1

# %%
# recruit_info.groupby(by=['number'])['number'].count()
# Out:
# number
# 1        2
# 2        2
# 3        2
# 4        2
# 5        2
#         ..
# 29268    1
# 29269    1
# 29270    1
# 29271    1
# 29272    1
# Name: number, Length: 29272, dtype: int64

# %%
# recruit_info.head()
# Out:
#    number  resource     company                            duty career degree  \
# 0       1  jobkorea  디휴브(DEHUV)                  [디휴브] 개발자 부문채용  신입·경력   학력무관
# 1       2  jobkorea    ㈜레미유코스메틱   브랜드 디자이너 / MD / (카페)쇼룸 매니저 채용     경력   학력무관
# 2       3  jobkorea         ㈜순진        마케팅 담당자 및 상품기획/MD 경력직 채용  경력2년↑    고졸↑
# 3       4  jobkorea    효성에프엠에스㈜  2021년 효성에프엠에스 신입사원 및 경력사원 공개채용  신입·경력    대졸↑
# 4       5  jobkorea      ㈜빗썸코리아               빗썸코리아 부문별 경력사원 채용     경력   학력무관
#
#   work_place                work_type  \
# 0     경기 고양시                      정규직
# 1     서울 성동구  정규직                 외\n
# 2     서울 광진구                      정규직
# 3     서울 강남구                      정규직
# 4     서울 강남구                      정규직
#
#                                             category  \
# 0  ['반응형 웹, 백엔드, 풀스택, 하이브리드 앱, 소프트웨어개발, BigData, ...
# 1  ['화장품, 마케팅, 마케팅기획, 브랜딩, 프로모션, 상품기획, 신상품개발, 온라인...
# 2  ['영상편집, 포토샵, 제품기획, 광고기획, 마케팅, 마케팅기획, 바이럴마케팅, 브...
# 3  ['Jira, Spring Framework, 모바일앱개발, 소프트웨어개발, 솔루션...
# 4  ['기획, 기획조사, 사업기획, 사업제휴, 서비스기획, 전략, 법무, 송무, 인허가...
#
#                                                 link  \
# 0  https://www.jobkorea.co.kr/Recruit/GI_Read/366...
# 1  https://www.jobkorea.co.kr/Recruit/GI_Read/366...
# 2  https://www.jobkorea.co.kr/Recruit/GI_Read/366...
# 3  https://www.jobkorea.co.kr/Recruit/GI_Read/366...
# 4  https://www.jobkorea.co.kr/Recruit/GI_Read/366...
#
#                                                 info
# 0  https://www.jobkorea.co.kr/Recruit/Co_Read/C/d...
# 1  https://www.jobkorea.co.kr/Recruit/Co_Read/C/l...
# 2  https://www.jobkorea.co.kr/Recruit/Co_Read/C/s...
# 3  https://www.jobkorea.co.kr/Recruit/Co_Read/C/h...
# 4  https://www.jobkorea.co.kr/Recruit/Co_Read/C/b...

# %%
# 데이터 읽어서 DB에 저장

# DB연동
conn = pymysql.connect(host='localhost',
                       database='shakeit', # 자기 데이터 베이스에 맞게 접속
                       user='root',
                       passwd='mysql', #자기 비밀번호
                       charset='utf8',
                       local_infile=1) #혹시나 안되면 이거 켜서 접속

cursor = conn.cursor()

value_list = []
for index, row in recruit_info.iterrows():
    tu = ( row.company, row.duty, row.career, row.degree,  row.work_place,
          row.work_type, row.category, row.link, row.info, row.resource) 
    value_list.append(tu)
    
cursor.executemany('''
                  INSERT INTO job (company_name, duty, career, degree, work_place, work_type, category, recruit_link, enterprises_link, resource) 
                  values ( %s, %s, %s, %s, %s, %s, %s, %s, %s,%s)
                  ''', value_list)

conn.commit()
conn.close()
