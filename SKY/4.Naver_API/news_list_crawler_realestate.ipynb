# %%
# 뉴스 
# 호황/불황 

# 빅스 지수맹키로 산업에 대한 분위기를 알아낼 수 는 있다이

# 감성어 사전(지도학습) / (비지도) 
# 도메인 마다 단어의 의미가 달라짐 ㅇㅅㅇ -> 추가적인 작업이 필요할지도 노가다*100000

# 동사, 형용사, 부사 
# 없는건 중립으로 처리됨
# 강도 설정도

# 감성어 사전 그대로 써도 나의 머리는 터지게찌
# 안되면 추가로 만들어 보면 되징 ㅇㅅㅇ

# IT 업종지수

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re

# %%
client_id = "mNhJ01jj6_6mlvwLR3uy" # 개발자센터에서 발급받은 Client ID 값
client_secret = "JAHWSRUs2D" # 개발자센터에서 발급받은 Client Secret 값


#query = urllib.parse.quote(input("뭐가 그리 궁금하드노: "))
encText = urllib.parse.quote('부동산')
idx = 0
display = 100
start = 1
end = 1000

web_df = pd.DataFrame(columns=('title', 'link', 'description', 'pubDate'))

for start_index in range(start, end, display): # 1 ~ 1000까지 100개씩 가지고 올끼야
    

    url = "https://openapi.naver.com/v1/search/news.json?query=" + encText \
            +'&display=' + str(display) \
            +'&sort=date' \
            +'&start=' + str(start_index)
             
    request = urllib.request.Request(url)

    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)

    response = urllib.request.urlopen(request)
    rescode = response.getcode()

    if(rescode==200):
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items'] 
        
        for item_index in range(0, len(items)):
            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag, '', items[item_index]['title'])
            link = items[item_index]['link']
            description = re.sub(remove_tag, '', items[item_index]['description'])
            pubDate = items[item_index]['pubDate']
            
            web_df.loc[idx] = [title, link, description, pubDate]
            idx += 1
            
    else: print("Error Code:" + rescode)

web_df
# Out:
#                                                  title  \
# 0                                    ‘부동산투기’ 전직 공무원 유죄
# 1                  (영상)은행권, 비금융 신사업 진출 본격화…알뜰폰 이어 배달까지
# 2                 &quot;은행에 부동산·유통 등 타업종 투자 허용해야&quot;
# 3                청와대, 다주택자 양도세 완화론 일축…“다음 정부에서 검토할 문제”
# 4    이재명, 선대위 개편 마무리...조동연 논란엔 &quot;국민 판단 지켜보겠다&quot;
# ..                                                 ...
# 995             오피스텔도 대기업 브랜드 선호...중견건설사보다 경쟁률 3.5배 높아
# 996                   개그맨 서경석, 재도전 끝에 공인중개사 합격…“기적적이다”
# 997                      [김창준] 볼커의 금리 인상에 무너진 일본의 폭풍성장
# 998         “'영역' 경계 없이 산업 혁신” 외친 하이브, 사업 확장 본격화… 주가는?
# 999                           대구·경북 소비자물가 근 10년 만에 최고치
#
#                                                   link  \
# 0    http://www.jndn.com/article.php?aid=1638442006...
# 1    https://news.naver.com/main/read.naver?mode=LS...
# 2    https://news.naver.com/main/read.naver?mode=LS...
# 3    https://news.naver.com/main/read.naver?mode=LS...
# 4    https://news.naver.com/main/read.naver?mode=LS...
# ..                                                 ...
# 995  http://www.dtnews24.com/news/articleView.html?...
# 996  https://news.naver.com/main/read.naver?mode=LS...
# 997  https://news.koreadaily.com/2021/12/01/society...
# 998         https://www.etoday.co.kr/news/view/2083398
# 999  https://news.naver.com/main/read.naver?mode=LS...
#
#                                            description  \
# 0    부동산 투기 혐의로 재판에 넘겨진 광주 광산구청 전직 간부 공무원이 유죄를 선고받았...
# 1    하나은행은 개인이 온라인 경매를 통해 중고차를 사고팔 수 있는 ‘원더카 직거래 경매...
# 2    은행연합회 '디지털시대의 금융 겸업주의' 세미나 은행도 부동산·유통 등 다양한 비(...
# 3    앞서 박완주 민주당 정책위의장은 “(다주택자 양도세 완화를) 배제하지 않고 검토하고...
# 4    후보는 부동산 정책을 문재인 정부의 가장 큰 실패 영역이라고 평가했습니다. 그러면서...
# ..                                                 ...
# 995  부동산전문 리서치업체 리얼투데이 관계자는 &quot;오피스텔은 분양보증 의무대상에 ...
# 996  참 재밌고 즐겁게 할 수 있겠다는 생각이 들었다&quot;고 시험에 도전하게 된 계...
# 997  올리자 부동산 가격 20% 폭락 눈을 감았다. 비만이 많은 미국. 그런 반면 뼈만 ...
# 998  라이선스업 △투자자문업 △부동산임대, 관리업 △정보서비스업 △자연공원 운영업 등이 ...
# 999  주요 등락품목을 보면 휘발유(35.3%), 경유(41.9%), 자동차용 LPG(36...
#
#                              pubDate
# 0    Thu, 02 Dec 2021 19:50:00 +0900
# 1    Thu, 02 Dec 2021 19:48:00 +0900
# 2    Thu, 02 Dec 2021 19:47:00 +0900
# 3    Thu, 02 Dec 2021 19:41:00 +0900
# 4    Thu, 02 Dec 2021 19:38:00 +0900
# ..                               ...
# 995  Thu, 02 Dec 2021 10:42:00 +0900
# 996  Thu, 02 Dec 2021 10:42:00 +0900
# 997  Thu, 02 Dec 2021 10:42:00 +0900
# 998  Thu, 02 Dec 2021 10:42:00 +0900
# 999  Thu, 02 Dec 2021 10:41:00 +0900
#
# [1000 rows x 4 columns]

# %%
web_df.columns
web_df["title_description"] = web_df["title"] + " " + web_df["description"]

# %%
web_df.to_csv("realestate.csv", index=False, encoding="utf-8")
