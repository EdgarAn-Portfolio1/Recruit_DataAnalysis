# %% [markdown]
# # https://developers.naver.com/docs/serviceapi/search/news/news.md#뉴스

# %% [markdown]
# # display 최대100 (한 요청당이 겠지)
# # 모듈화 라는거 하면 더 빨리 긁을수 있을지도

# %% [markdown]
# # https://www.youtube.com/watch?v=C8-SII6S4Bc

# %%
# 뉴스 
# 호황/불황 

# 빅스 지수맹키로 산업에 대한 분위기를 알아낼 수 는 있다이

# 감성어 사전(지도학습) / (비지도) 
# 도메인 마다 단어의 의미가 달라짐 ㅇㅅㅇ -> 추가적인 작업이 필요할지도 노가다*100000

# 동사, 형용사, 부사 
# 없는건 중립으로 처리됨
# 강도 설정도

# 감성어 사전 그대로 써도 나의 머리는 터지게찌
# 안되면 추가로 만들어 보면 되징 ㅇㅅㅇ

# IT 업종지수

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re

# %%
client_id = "mNhJ01jj6_6mlvwLR3uy" # 개발자센터에서 발급받은 Client ID 값
client_secret = "JAHWSRUs2D" # 개발자센터에서 발급받은 Client Secret 값


#query = urllib.parse.quote(input("뭐가 그리 궁금하드노: "))
encText = urllib.parse.quote('취업 "it"')
idx = 0
display = 100
start = 1
end = 1000

web_df = pd.DataFrame(columns=('title', 'link', 'description', 'pubDate'))

for start_index in range(start, end, display): # 1 ~ 1000까지 100개씩 가지고 올끼야
    

    url = "https://openapi.naver.com/v1/search/news.json?query=" + encText \
            +'&display=' + str(display) \
            +'&sort=date' \
            +'&start=' + str(start_index)
             
    request = urllib.request.Request(url)

    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)

    response = urllib.request.urlopen(request)
    rescode = response.getcode()

    if(rescode==200):
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items'] 
        
        for item_index in range(0, len(items)):
            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag, '', items[item_index]['title'])
            link = items[item_index]['link']
            description = re.sub(remove_tag, '', items[item_index]['description'])
            pubDate = items[item_index]['pubDate']
            
            web_df.loc[idx] = [title, link, description, pubDate]
            idx += 1
            
    else: print("Error Code:" + rescode)

web_df
# Out:
#                                                  title  \
# 0                   구직사이트 데이터·인턴십 지원…정부, 청년 디지털 지원책 발표
# 1                        정부, 디지털 청년 지원 대폭 확대…비전공자도 챙긴다
# 2                        올해 직업계고 취업률 55%…‘1년 내 퇴사’ 35%
# 3                    배재대 IPP사업단, IT관련 기업 15곳 초청 설명회 열어
# 4                 [교육소식]배재대 IPP사업단, 일학습병행사업 IT기업 설명회 등
# ..                                                 ...
# 995  [Startup’s Story #462] ‘3D 커스텀 안경을 넘어 스마트 글라스까...
# 996                      KT&amp;G, 2021년 신입·경력사원 공개 채용
# 997                      인턴 월급 300만원…케이뱅크로 금융 취업문 열어볼까
# 998       KT&amp;G, 올해 신입‧경력사원 공개 채용 실시...블라인드 방식으로 진행
# 999                         KT&amp;G, 신입·경력사원 공개 채용 실시
#
#                                                   link  \
# 0    https://news.naver.com/main/read.naver?mode=LS...
# 1    https://news.naver.com/main/read.naver?mode=LS...
# 2    https://news.naver.com/main/read.naver?mode=LS...
# 3    http://news.unn.net/news/articleView.html?idxn...
# 4    https://news.naver.com/main/read.naver?mode=LS...
# ..                                                 ...
# 995                  https://platum.kr/archives/174428
# 996  http://www.asiaa.co.kr/news/articleView.html?i...
# 997  https://news.naver.com/main/read.naver?mode=LS...
# 998  http://www.todaykorea.co.kr/news/articleView.h...
# 999  http://www.chungnamilbo.co.kr/news/articleView...
#
#                                            description  \
# 0    먼저 학생과 취업준비생에게는 이달부터 구직사이트에 대한 데이터 이용료 면제, 데이터...
# 1    학생·취업준비생 1000명에게 내년부터 교육과정 설계 및 취·창업 멘토링을 제공하기...
# 2    전체 졸업자 대비 진학률은 45%로, 취업자(2만2583명) 보다 진학자(3만552...
# 3    등 IT관련 기업 15곳을 초청해 1일 설명회를 가졌다. 설명회에는 AI·SW창의융...
# 4    일학습병행사업은 IT와 바이오, 마케팅 관련분야 기업에 모두 30명을 선발, 파견한...
# ..                                                 ...
# 995  청년 창업이 장려되야 하는 것은 많지만, 낮은 취업률의 대안으로 제시되는 것은 위험...
# 996  6급·원급 신입사원 모집 분야는 △경영관리/기획 △부동산 △IT △제조 △원료 △R...
# 997  하늘에 별따기가 된 금융권 취업의 열쇠나 마찬가지다. 인터넷 전문은행 케이뱅크가 출...
# 998  6급·원급 신입사원 모집 분야는 △경영관리/기획 △부동산 △IT △제조 △원료 △R...
# 999  6급·원급 신입사원 모집 분야는 경영관리·기획, 부동산, IT, 제조, 원료, R&...
#
#                              pubDate
# 0    Thu, 02 Dec 2021 14:24:00 +0900
# 1    Thu, 02 Dec 2021 14:16:00 +0900
# 2    Thu, 02 Dec 2021 14:13:00 +0900
# 3    Thu, 02 Dec 2021 14:02:00 +0900
# 4    Thu, 02 Dec 2021 13:43:00 +0900
# ..                               ...
# 995  Mon, 15 Nov 2021 14:02:00 +0900
# 996  Mon, 15 Nov 2021 13:36:00 +0900
# 997  Mon, 15 Nov 2021 13:36:00 +0900
# 998  Mon, 15 Nov 2021 13:20:00 +0900
# 999  Mon, 15 Nov 2021 13:18:00 +0900
#
# [1000 rows x 4 columns]

# %%
web_df.columns
web_df["title_description"] = web_df["title"] + " " + web_df["description"]

# %%
web_df.to_csv("news-list.csv", index=False, encoding="utf-8")

# %%
단어 점수
