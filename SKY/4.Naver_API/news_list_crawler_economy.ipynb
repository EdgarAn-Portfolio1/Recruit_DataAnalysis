# %% [markdown]
# # https://developers.naver.com/docs/serviceapi/search/news/news.md#뉴스

# %% [markdown]
# # display 최대100 (한 요청당이 겠지)
# # 모듈화 라는거 하면 더 빨리 긁을수 있을지도

# %% [markdown]
# # https://www.youtube.com/watch?v=C8-SII6S4Bc

# %%
# 뉴스 
# 호황/불황 

# 빅스 지수맹키로 산업에 대한 분위기를 알아낼 수 는 있다이

# 감성어 사전(지도학습) / (비지도) 
# 도메인 마다 단어의 의미가 달라짐 ㅇㅅㅇ -> 추가적인 작업이 필요할지도 노가다*100000

# 동사, 형용사, 부사 
# 없는건 중립으로 처리됨
# 강도 설정도

# 감성어 사전 그대로 써도 나의 머리는 터지게찌
# 안되면 추가로 만들어 보면 되징 ㅇㅅㅇ

# IT 업종지수

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re

# %%
client_id = "mNhJ01jj6_6mlvwLR3uy" # 개발자센터에서 발급받은 Client ID 값
client_secret = "JAHWSRUs2D" # 개발자센터에서 발급받은 Client Secret 값


#query = urllib.parse.quote(input("뭐가 그리 궁금하드노: "))
encText = urllib.parse.quote('경제')
idx = 0
display = 100
start = 1
end = 1000

web_df = pd.DataFrame(columns=('title', 'link', 'description', 'pubDate'))

for start_index in range(start, end, display): # 1 ~ 1000까지 100개씩 가지고 올끼야
    

    url = "https://openapi.naver.com/v1/search/news.json?query=" + encText \
            +'&display=' + str(display) \
            +'&sort=date' \
            +'&start=' + str(start_index)
             
    request = urllib.request.Request(url)

    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)

    response = urllib.request.urlopen(request)
    rescode = response.getcode()

    if(rescode==200):
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items'] 
        
        for item_index in range(0, len(items)):
            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag, '', items[item_index]['title'])
            link = items[item_index]['link']
            description = re.sub(remove_tag, '', items[item_index]['description'])
            pubDate = items[item_index]['pubDate']
            
            web_df.loc[idx] = [title, link, description, pubDate]
            idx += 1
            
    else: print("Error Code:" + rescode)

web_df
# Out:
#                                                  title  \
# 0    [퀄컴 스냅드래곤 서밋 2021] 알렉스 카투지안 &quot;디지털과 현실 합쳐져....
# 1                       광주시, 수소생산기지 착공…반경 70㎞ 수소 공급 가능
# 2                  대구한의대, 대한민국 농촌재능나눔대상서 농림축산식품부장관상 수상
# 3    [주목! 2022 대선공약] 김동연 &quot;분권형 대통령제 도입, 국회의원 3선...
# 4                 스마트시티·스타트업 분야 전문가 한 자리에…국제심포지엄 7일 개최
# ..                                                 ...
# 995  ['퇴근길' 한눈에 훑는 뉴스] 기재부 &quot;다주택자 양도세 완화 계획 없어....
# 996           靑 &quot;다주택자 양도세 인하는 다음 정부서 검토할 문제&quot;
# 997                                  가혹한 정치는 호랑이보다 무섭다
# 998                  [성승제칼럼] '구원투수' 떠오른 30대 리더의 기대와 우려
# 999                 윤석열, '이준석 패싱' 뒤로 하고 마이웨이…귀경 첫날 강행군
#
#                                                   link  \
# 0    http://www.econovill.com/news/articleView.html...
# 1    http://www.smartfn.co.kr/view.php?ud=202112021...
# 2    https://news.naver.com/main/read.naver?mode=LS...
# 3    https://news.naver.com/main/read.naver?mode=LS...
# 4    https://ilyo.co.kr/?ac=article_view&entry_id=4...
# ..                                                 ...
# 995  http://www.newsquest.co.kr/news/articleView.ht...
# 996  https://news.naver.com/main/read.naver?mode=LS...
# 997  https://www.inews365.com/news/article.html?no=...
# 998  http://www.pressm.kr/news/articleView.html?idx...
# 999  https://news.naver.com/main/read.naver?mode=LS...
#
#                                            description  \
# 0    다양한 경제 부문에서도 상호 작용할 수 있다&quot;고 말했다. 그가 오큘러스의 ...
# 1    수소경제 활성화 기반 구축 광주시가 2일 광산구 평동3차산업단지에서 광주 수소생산기...
# 2    대구한의대는 지난 5년간 농촌지역 9천여 명의 주민을 대상으로 지역 경제 활성화, ...
# 3    대선출마를 선언한 김동연 전 경제부총리가 분권형 대통령제를 도입하고 국회의원 3선 ...
# 4    디지털경제부 장관을 비롯한 우리나라와 프랑스의 전문가들이 스마트시티·스타트업 관련 ...
# ..                                                 ...
# 995  [경제] ◇ 기재부 &quot;다주택자 양도세 완화 계획 없어...부작용 커&quo...
# 996  국회에서 경항공모함 사업 예산 편성으로 인해 예산안 합의가 진통을 겪는 것에 대해선...
# 997  잘못이 없는데도 억울한 피해를 당해 감당키 어려운 경제적 부담으로 나타날 수 있다....
# 998  '나이가 벼슬'이라는 인식에서 벗어나 한국의 정치권과 경제권이 더 젊어지고 역동적인...
# 999  이어 윤 후보는 &quot;경제적 부가가치 창출을 넘어 도전과 혁신, 성장의 가치를...
#
#                              pubDate
# 0    Thu, 02 Dec 2021 19:54:00 +0900
# 1    Thu, 02 Dec 2021 19:54:00 +0900
# 2    Thu, 02 Dec 2021 19:53:00 +0900
# 3    Thu, 02 Dec 2021 19:52:00 +0900
# 4    Thu, 02 Dec 2021 19:52:00 +0900
# ..                               ...
# 995  Thu, 02 Dec 2021 17:18:00 +0900
# 996  Thu, 02 Dec 2021 17:18:00 +0900
# 997  Thu, 02 Dec 2021 17:18:00 +0900
# 998  Thu, 02 Dec 2021 17:18:00 +0900
# 999  Thu, 02 Dec 2021 17:18:00 +0900
#
# [1000 rows x 4 columns]

# %%
web_df.columns
web_df["title_description"] = web_df["title"] + " " + web_df["description"]

# %%
web_df.to_csv("economy.csv", index=False, encoding="utf-8")
